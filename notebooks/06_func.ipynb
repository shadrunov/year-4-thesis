# %%
import json
import os
import re
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colormaps

# %% [markdown]
# # get clear data
#
# что хотим получить
#
# для анализа качества: пресижн рекол экьюраси
# * образ — ос
# * для каждого образа сет из уязвимостей
#     * уязвимость (сет с уязвимостями и рхса?) — пакет (сеты с пакетами) — скор — год уязвимости
#
# * зависимость от ос? в каких ос больше уязвимостей находится
# * зависимость от пакетов? в каких пакетах больше всего уязвимостей
# * старые и до сих пор находятся? частота встречаемости уязвимостей, самые частые, самые старые, распределение по годам
# * распределение по скору. также плотность скор — год
# * анализ качества сканеров для
#
# * per image
# * per

# %%
tags = json.load(open("../tags/tags_random_amd64/tags_flat_3000.json"))
len(tags)
# Out:
# 3207

# %%
scanners = ["clair", "gc", "grype", "scout", "snyk", "trivy"]

# %%
data = {}
for sc in scanners:
    print("reading", sc)
    with open(f"../final_results/src/{sc}_tags_vulns.json", "r") as f:
        data[sc] = json.load(f)
# Out:
# reading clair
# reading gc
# reading grype
# reading scout
# reading snyk
# reading trivy

# %% [markdown]
# # отфильтровали теги

# %%
per_tag = []
error_tags = []

for tag in tags:
    counter = 0
    t = {"tag": tag}
    t["counter"] = sum([tag in data[s] for s in scanners])
    if sum([tag in data[s] for s in scanners]) < 5:
        error_tags.append(tag)
    per_tag.append(t)
error_tags
# Out:
# ['vito/git-branch-heads-resource:latest',
#  'zarplata/concourse-git-bitbucket-pr-resource:1.2.3',
#  'zarplata/concourse-git-bitbucket-pr-resource:latest',
#  'zarplata/concourse-git-bitbucket-pr-resource:1.2.4',
#  'mattermost/mattermost-team-edition:1d5b47a',
#  'mattermost/mattermost-team-edition:5ce0c57',
#  'mprasil/bitwarden:latest',
#  'kubernetes/pause:10.11.6-x86_64',
#  'kubernetes/pause:10.11.4',
#  'kubernetes/pause:10.11.2',
#  'minio/console:v0.15.2',
#  'minio/console:v0.26.1',
#  'minio/console:v0.17.1',
#  'lsstsqre/sciplat-lab:d_2023_07_01',
#  'ackstorm/relk-filebeat:v7.2.0',
#  'ackstorm/relk-filebeat:v6']

# %%
tags = list(set(tags) - set(error_tags))
len(tags)
# Out:
# 3191

# %% [markdown]
# # reorder data
#
# * кладём в папку джейсоны tag.json
# * внутри clair ...., gc ..., и так далее

# %%
data.keys()
# Out:
# dict_keys(['clair', 'gc', 'grype', 'scout', 'snyk', 'trivy'])

# %%
per_tag = []

for tag in tags:
    t = {"tag": tag}
    for s in scanners:
        list_from_s = data[s].get(tag, [])
        t[s] = list_from_s
    per_tag.append(t)

# %%
pd.DataFrame.from_dict(per_tag)
# Out:
#                                                     tag  \
# 0              databus23/concourse-swift-resource:1.0.0
# 1              apicurio/apicurio-studio-ui:0.2.54.Final
# 2     governmentpaas/curl-ssl:0d0f9395c8643e96813a60...
# 3              bitnami/external-dns:0.12.2-debian-11-r0
# 4                     datadog/cluster-agent:7.45.1-rc.1
# ...                                                 ...
# 3186                                cypress/base:16.5.0
# 3187                               casanode/welcome:x86
# 3188                      grafana/promtail:main-209b281
# 3189                  casanode/syslog:x86-develop-2.0.1
# 3190  logdna/logdna-agent:3.5.7-20231127.585fba28aad...
#
#                                                   clair  \
# 0                                                    []
# 1                                                    []
# 2     [{'id': 'CVE-2023-38039', 'cve_id': 'CVE-2023-...
# 3     [{'id': 'CVE-2021-46828', 'cve_id': 'CVE-2021-...
# 4     [{'id': 'CVE-2023-4806', 'cve_id': 'CVE-2023-4...
# ...                                                 ...
# 3186  [{'id': 'CVE-2023-4421', 'cve_id': 'CVE-2023-4...
# 3187  [{'id': 'CVE-2019-13627', 'cve_id': 'CVE-2019-...
# 3188  [{'id': 'CVE-2023-3817', 'cve_id': 'CVE-2023-3...
# 3189                                                 []
# 3190  [{'id': 'CVE-2021-3997', 'cve_id': 'CVE-2021-3...
#
#                                                      gc  \
# 0                                                    []
# 1     [{'id': 'CVE-2021-43527', 'cve_id': 'CVE-2021-...
# 2     [{'id': 'CVE-2023-38545', 'cve_id': 'CVE-2023-...
# 3     [{'id': 'CVE-2023-29404', 'cve_id': 'CVE-2023-...
# 4     [{'id': 'CVE-2023-29405', 'cve_id': 'CVE-2023-...
# ...                                                 ...
# 3186  [{'id': 'CVE-2021-3177', 'cve_id': 'CVE-2021-3...
# 3187  [{'id': 'CVE-2019-14697', 'cve_id': 'CVE-2019-...
# 3188  [{'id': 'CVE-2023-24538', 'cve_id': 'CVE-2023-...
# 3189  [{'id': 'CVE-2017-16997', 'cve_id': 'CVE-2017-...
# 3190  [{'id': 'CVE-2019-20916', 'cve_id': 'CVE-2019-...
#
#                                                   grype  \
# 0     [{'id': 'CVE-2022-48174', 'cve_id': 'CVE-2022-...
# 1     [{'id': 'CVE-2020-10727', 'cve_id': 'CVE-2020-...
# 2     [{'id': 'CVE-2023-38545', 'cve_id': 'CVE-2023-...
# 3     [{'id': 'CVE-2011-3374', 'cve_id': 'CVE-2011-3...
# 4     [{'id': 'CVE-2022-3715', 'cve_id': 'CVE-2022-3...
# ...                                                 ...
# 3186  [{'id': 'CVE-2021-39135', 'cve_id': 'CVE-2021-...
# 3187  [{'id': 'CVE-2022-48174', 'cve_id': 'CVE-2022-...
# 3188  [{'id': 'CVE-2011-3374', 'cve_id': 'CVE-2011-3...
# 3189  [{'id': 'CVE-2019-9924', 'cve_id': 'CVE-2019-9...
# 3190  [{'id': 'GHSA-g98v-hv3f-hcfr', 'cve_id': '', '...
#
#                                                   scout  \
# 0                                                    []
# 1     [{'id': 'CVE-2014-9939', 'cve_id': 'CVE-2014-9...
# 2     [{'id': 'CVE-2023-38546', 'cve_id': 'CVE-2023-...
# 3     [{'id': 'CVE-2023-39804', 'cve_id': 'CVE-2023-...
# 4     [{'id': 'CVE-2023-45288', 'cve_id': 'CVE-2023-...
# ...                                                 ...
# 3186  [{'id': 'CVE-2023-39804', 'cve_id': 'CVE-2023-...
# 3187  [{'id': 'CVE-2019-1563', 'cve_id': 'CVE-2019-1...
# 3188  [{'id': 'CVE-2023-39804', 'cve_id': 'CVE-2023-...
# 3189                                                 []
# 3190  [{'id': 'GHSA-g98v-hv3f-hcfr', 'cve_id': '', '...
#
#                                                    snyk  \
# 0                                                    []
# 1     [{'id': 'CVE-2015-5186', 'cve_id': 'CVE-2015-5...
# 2     [{'id': 'CVE-2023-38039', 'cve_id': 'CVE-2023-...
# 3     [{'id': 'CVE-2011-3374', 'cve_id': 'CVE-2011-3...
# 4     [{'id': 'CVE-2022-3715', 'cve_id': 'CVE-2022-3...
# ...                                                 ...
# 3186  [{'id': 'CVE-2016-1585', 'cve_id': 'CVE-2016-1...
# 3187  [{'id': 'CVE-2019-12900', 'cve_id': 'CVE-2019-...
# 3188  [{'id': 'CVE-2011-3374', 'cve_id': 'CVE-2011-3...
# 3189                                                 []
# 3190  [{'id': 'CVE-2019-12900', 'cve_id': 'CVE-2019-...
#
#                                                   trivy
# 0                                                    []
# 1     [{'id': 'CVE-2015-5186', 'cve_id': 'CVE-2015-5...
# 2     [{'id': 'CVE-2023-38545', 'cve_id': 'CVE-2023-...
# 3     [{'id': 'CVE-2011-3374', 'cve_id': 'CVE-2011-3...
# 4     [{'id': 'CVE-2022-3715', 'cve_id': 'CVE-2022-3...
# ...                                                 ...
# 3186  [{'id': 'CVE-2011-3374', 'cve_id': 'CVE-2011-3...
# 3187  [{'id': 'CVE-2020-15999', 'cve_id': 'CVE-2020-...
# 3188  [{'id': 'CVE-2011-3374', 'cve_id': 'CVE-2011-3...
# 3189                                                 []
# 3190  [{'id': 'CVE-2019-12900', 'cve_id': 'CVE-2019-...
#
# [3191 rows x 7 columns]

# %%
tag = "whenlambomoon/zend:latest"

# %% [markdown]
# # score
#
# * true positive — сканер назвал уязвимость и другие тоже назвали
# * false positive — сканер назвал уязвимость и другие не назвали
# * true negative — сканер не назвал уязвимость и другие не назвали — не можем посчитать
# * false negative — сканер не назвал уязвимость, а другие назвали
#
#
# * плюс степень — 1 другой сканер, 2 других сканера, 3 других сканера?
#
#
# * `cum[key]["cl_truepos"] = len(cum[key]["conf_by_two"] & cves["cl"][key])`
# * `cum[key]["cl_falseneg"] = len(cum[key]["conf_by_two"] - cves["cl"][key])`
# * `cum[key]["cl_falsepos"] = len(cves["cl"][key] - cum[key]["conf_by_two"])`

# %%
s_num = len(scanners)
s_other_num = s_num - 1

# %% [markdown]
# # проставить айди

# %%
def set_id(d: dict):
    for s in scanners:
        counter = 0
        for entry in d[s]:
            entry["uid"] = s + str(counter)
            counter += 1

# %% [markdown]
# # агрегированные записи
#
# ```json
# {
#     "uid": "aggr1",
#     "links": [clair1, gc55]
# }
# ```

# %%
def get_aggr_entry_by_link(d: dict, s: str, uid):
    for i in d["aggr"]:
        links = sum(i["links"].values(),[])
        if uid in links:
            return i["uid"]
    return None

# %%
def get_similar_from_scanner(entry: dict, tag_data: dict, s: str) -> str:
    s_entries = tag_data[s]
    res = []
    for s_entry in s_entries:
        for id in entry["sas"]:
            if id in s_entry["sas"]:
                res.append(s_entry["uid"])
    return res

# %%
def make_aggr_entries(d: dict):
    d["aggr"] = []
    counter = 0
    for s in scanners:
        for entry in d[s]:
            r = get_aggr_entry_by_link(d, s, entry["uid"])
            if r:  # есть аггр запись с этой записью из сканера
                pass
                # print(f"found {entry['uid']} in {r}")
            else:  # эта запись сканера не встречается в других
                aggr = {"uid": f"aggr{counter}"}
                links = {}
                for s in scanners:
                    similar = get_similar_from_scanner(entry, d, s)
                    similar = list(set(similar))
                    links[s] = similar
                aggr["links"] = links
                d["aggr"].append(aggr)
                counter += 1
                # print(f'{entry["uid"]} not found. created {aggr}')

# %% [markdown]
# # conf

# %%
def set_confirmed_data(d):
    for entry in d["aggr"]:
        entry["conf"] = {}
        # print(entry)
        for s in scanners:
            if entry["links"][s]:
                entry["conf"][s] = True
            else:
                entry["conf"][s] = False

        entry["conf_count"] = sum(entry["conf"].values())
        entry["conf_count_others"] = entry["conf_count"] - 1
        entry["conf_rate"] = entry["conf_count_others"] / s_other_num
        # print(entry)

# %% [markdown]
# # дальше работаем с агрегатными записями

# %% [markdown]
# # tp
#
# для каждого сканера посчитать число тру позитив образов
#
# сканер назвал уязвимость и другие тоже назвали
#
# число других — хотя бы 1

# %%
# print

json.dump(d, open("d.json", "w"), indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # print
# ----> 3 json.dump(d, open("d.json", "w"), indent=4)
#
# NameError: name 'd' is not defined

# %%
others = 1

# %%
def set_tp(d):
    d["res"]["tp"] = {"num": {}, "data": {}}
    for s in scanners:
        d["res"]["tp"]["data"][s] = []
        d["res"]["tp"]["num"][s] = None

    for e in d["aggr"]:
        if e["conf_count_others"] >= others:
            for s in scanners:
                if e["conf"][s]:
                    d["res"]["tp"]["data"][s].append(e["uid"])

    for s in scanners:
        d["res"]["tp"]["num"][s] = len(set(d["res"]["tp"]["data"][s]))

# %% [markdown]
# # fp
#
# false positive — сканер назвал уязвимость и другие не назвали

# %%
def set_fp(d):
    d["res"]["fp"] = {"num": {}, "data": {}}
    for s in scanners:
        d["res"]["fp"]["data"][s] = []
        d["res"]["fp"]["num"][s] = None

    for e in d["aggr"]:
        if e["conf_count_others"] < others:
            for s in scanners:
                if e["conf"][s]:
                    d["res"]["fp"]["data"][s].append(e["uid"])

    for s in scanners:
        d["res"]["fp"]["num"][s] = len(set(d["res"]["fp"]["data"][s]))

# %% [markdown]
# # fn
#
# * false negative — сканер не назвал уязвимость, а другие назвали

# %%
def set_fn(d):
    d["res"]["fn"] = {"num": {}, "data": {}}
    for s in scanners:
        d["res"]["fn"]["data"][s] = []
        d["res"]["fn"]["num"][s] = None


    for e in d["aggr"]:
        if e["conf_count_others"] >= others:
            for s in scanners:
                if not e["conf"][s]:
                    d["res"]["fn"]["data"][s].append(e["uid"])

    for s in scanners:
        d["res"]["fn"]["num"][s] = len(set(d["res"]["fn"]["data"][s]))

# %% [markdown]
# # tn
#
# * true negative — сканер не назвал уязвимость и другие не назвали

# %%
def set_tn(d):
    d["res"]["tn"] = {"num": {}, "data": {}}
    for s in scanners:
        d["res"]["tn"]["data"][s] = []
        d["res"]["tn"]["num"][s] = None


    for e in d["aggr"]:
        if e["conf_count_others"] < others:
            for s in scanners:
                if not e["conf"][s]:
                    d["res"]["tn"]["data"][s].append(e["uid"])

    for s in scanners:
        d["res"]["tn"]["num"][s] = len(set(d["res"]["tn"]["data"][s]))

# %% [markdown]
# # metrics

# %% [markdown]
# # precision
# * tp / (tp + fp)

# %%
def set_precision(d):
    d["metrics"]["precision"] = {}
    for s in scanners:
        d["metrics"]["precision"][s] = None


    for s in scanners:
        tp = d["res"]["tp"]["num"][s]
        fp = d["res"]["fp"]["num"][s]
        if tp + fp == 0:
            d["metrics"]["precision"][s] = 1
        else:
            d["metrics"]["precision"][s] = tp / (tp + fp)

# %% [markdown]
# # recall
# * tp / (tp + fn)

# %%
def set_recall(d):
    d["metrics"]["recall"] = {}
    for s in scanners:
        d["metrics"]["recall"][s] = None


    for s in scanners:
        tp = d["res"]["tp"]["num"][s]
        fn = d["res"]["fn"]["num"][s]
        if tp + fn == 0:
            d["metrics"]["recall"][s] = 0
        else:
            d["metrics"]["recall"][s] = tp / (tp + fn)

# %% [markdown]
# # accuracy
# * (tp + tn) / (tp + fp + fn + tn)

# %%
def set_accuracy(d):
    d["metrics"]["accuracy"] = {}
    for s in scanners:
        d["metrics"]["accuracy"][s] = None


    for s in scanners:
        tp = d["res"]["tp"]["num"][s]
        fp = d["res"]["fp"]["num"][s]
        fn = d["res"]["fn"]["num"][s]
        tn = d["res"]["tn"]["num"][s]
        if tp + fp + fn + tn == 0:
            d["metrics"]["accuracy"][s] = None
        else:
            d["metrics"]["accuracy"][s] = (tp + tn) / (tp + fp + fn + tn)

# %% [markdown]
# # f1
# * 2 * precision * recall / (precision + recall)

# %%
def set_f1(d):
    d["metrics"]["f1"] = {}
    for s in scanners:
        d["metrics"]["f1"][s] = None


    for s in scanners:
        precision = d["metrics"]["precision"][s]
        recall = d["metrics"]["recall"][s]
        if precision + recall == 0:
            d["metrics"]["f1"][s] = None
        else:
            d["metrics"]["f1"][s] = 2 * precision * recall / (precision + recall)

# %%
def process_d(d):
    set_id(d)
    make_aggr_entries(d)
    set_confirmed_data(d)

    d["res"] = {}
    set_tp(d)
    set_fp(d)
    set_fn(d)
    set_tn(d)

    d["metrics"] = {}
    set_precision(d)
    set_recall(d)
    set_accuracy(d)
    set_f1(d)

# %% [markdown]
# # big process

# %%
counter = 0
for tag in tags:
    d = next(t for t in per_tag if t["tag"] == tag)
    process_d(d)
    counter += 1
    if counter % 100 == 0:
        print(counter)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100

# %%
counter = 0
for tag in tags:
    d = next(t for t in per_tag if t["tag"] == tag)
    filename = tag.replace(":", "_").replace("/", "_")
    with open(f"../final_results/per_tag_res/{filename}.json", "w") as f:
        json.dump(d, f, indent=4)
    counter += 1
    if counter % 100 == 0:
        print(counter)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100

# %% [markdown]
# # only numbers

# %%
numbers = []

# %%
for tag in tags:
    d = next(t for t in per_tag if t["tag"] == tag)
    res = {
        "tag": tag,
        "tp": d["res"]["tp"]["num"],
        "fp": d["res"]["fp"]["num"],
        "fn": d["res"]["fn"]["num"],
        "tn": d["res"]["tn"]["num"],
        "precision": d["metrics"]["precision"],
        "recall": d["metrics"]["recall"],
        "accuracy": d["metrics"]["accuracy"],
        "f1": d["metrics"]["f1"],
    }
    numbers.append(res)

# %%
numbers
# Out:
# [{'tag': 'weaveworksdemos/user-db:6bc65ab9fd43a905a050906a026eae8847fed979',
#   'tp': {'clair': 0,
#    'gc': 155,
#    'grype': 155,
#    'scout': 0,
#    'snyk': 157,
#    'trivy': 96},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 1, 'trivy': 0},
#   'fn': {'clair': 157,
#    'gc': 2,
#    'grype': 2,
#    'scout': 157,
#    'snyk': 0,
#    'trivy': 61},
#   'tn': {'clair': 1, 'gc': 1, 'grype': 1, 'scout': 1, 'snyk': 0, 'trivy': 1},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1,
#    'snyk': 0.9936708860759493,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.9872611464968153,
#    'grype': 0.9872611464968153,
#    'scout': 0.0,
#    'snyk': 1.0,
#    'trivy': 0.6114649681528662},
#   'accuracy': {'clair': 0.006329113924050633,
#    'gc': 0.9873417721518988,
#    'grype': 0.9873417721518988,
#    'scout': 0.006329113924050633,
#    'snyk': 0.9936708860759493,
#    'trivy': 0.6139240506329114},
#   'f1': {'clair': 0.0,
#    'gc': 0.9935897435897436,
#    'grype': 0.9935897435897436,
#    'scout': 0.0,
#    'snyk': 0.9968253968253968,
#    'trivy': 0.7588932806324111}},
#  {'tag': 'docker/ucp-interlock-proxy:3.3.0-beta1',
#   'tp': {'clair': 11,
#    'gc': 10,
#    'grype': 11,
#    'scout': 11,
#    'snyk': 11,
#    'trivy': 11},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 57, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 1, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 57,
#    'gc': 57,
#    'grype': 0,
#    'scout': 57,
#    'snyk': 57,
#    'trivy': 57},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.16176470588235295,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 1.0,
#    'gc': 0.9090909090909091,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'accuracy': {'clair': 1.0,
#    'gc': 0.9852941176470589,
#    'grype': 0.16176470588235295,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'f1': {'clair': 1.0,
#    'gc': 0.9523809523809523,
#    'grype': 0.27848101265822783,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0}},
#  {'tag': 'jrottenberg/ffmpeg:4.2.8-rockylinux8',
#   'tp': {'clair': 0,
#    'gc': 38,
#    'grype': 42,
#    'scout': 42,
#    'snyk': 41,
#    'trivy': 35},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 221, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 42, 'gc': 4, 'grype': 0, 'scout': 0, 'snyk': 1, 'trivy': 7},
#   'tn': {'clair': 221,
#    'gc': 221,
#    'grype': 0,
#    'scout': 221,
#    'snyk': 221,
#    'trivy': 221},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 0.1596958174904943,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.9047619047619048,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.9761904761904762,
#    'trivy': 0.8333333333333334},
#   'accuracy': {'clair': 0.8403041825095057,
#    'gc': 0.9847908745247148,
#    'grype': 0.1596958174904943,
#    'scout': 1.0,
#    'snyk': 0.9961977186311787,
#    'trivy': 0.973384030418251},
#   'f1': {'clair': 0.0,
#    'gc': 0.9500000000000001,
#    'grype': 0.2754098360655738,
#    'scout': 1.0,
#    'snyk': 0.9879518072289156,
#    'trivy': 0.9090909090909091}},
#  {'tag': 'praqma/network-multitool:extra',
#   'tp': {'clair': 139,
#    'gc': 138,
#    'grype': 139,
#    'scout': 139,
#    'snyk': 139,
#    'trivy': 139},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 110, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 1, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 110,
#    'gc': 110,
#    'grype': 0,
#    'scout': 110,
#    'snyk': 110,
#    'trivy': 110},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.5582329317269076,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 1.0,
#    'gc': 0.9928057553956835,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'accuracy': {'clair': 1.0,
#    'gc': 0.9959839357429718,
#    'grype': 0.5582329317269076,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'f1': {'clair': 1.0,
#    'gc': 0.996389891696751,
#    'grype': 0.7164948453608248,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0}},
#  {'tag': 'runatlantis/atlantis:v0.10.0',
#   'tp': {'clair': 42,
#    'gc': 156,
#    'grype': 165,
#    'scout': 141,
#    'snyk': 64,
#    'trivy': 91},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 85, 'scout': 7, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 123,
#    'gc': 9,
#    'grype': 0,
#    'scout': 24,
#    'snyk': 101,
#    'trivy': 74},
#   'tn': {'clair': 92,
#    'gc': 93,
#    'grype': 8,
#    'scout': 86,
#    'snyk': 93,
#    'trivy': 93},
#   'precision': {'clair': 0.9767441860465116,
#    'gc': 1.0,
#    'grype': 0.66,
#    'scout': 0.9527027027027027,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.2545454545454545,
#    'gc': 0.9454545454545454,
#    'grype': 1.0,
#    'scout': 0.8545454545454545,
#    'snyk': 0.3878787878787879,
#    'trivy': 0.5515151515151515},
#   'accuracy': {'clair': 0.5193798449612403,
#    'gc': 0.9651162790697675,
#    'grype': 0.6705426356589147,
#    'scout': 0.8798449612403101,
#    'snyk': 0.6085271317829457,
#    'trivy': 0.7131782945736435},
#   'f1': {'clair': 0.4038461538461538,
#    'gc': 0.9719626168224299,
#    'grype': 0.7951807228915663,
#    'scout': 0.9009584664536742,
#    'snyk': 0.5589519650655022,
#    'trivy': 0.7109375}},
#  {'tag': 'vastdataorg/csi:v2.2.1',
#   'tp': {'clair': 41,
#    'gc': 40,
#    'grype': 41,
#    'scout': 40,
#    'snyk': 26,
#    'trivy': 40},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 24, 'scout': 1, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 1, 'gc': 2, 'grype': 1, 'scout': 2, 'snyk': 16, 'trivy': 2},
#   'tn': {'clair': 25,
#    'gc': 25,
#    'grype': 1,
#    'scout': 24,
#    'snyk': 25,
#    'trivy': 25},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.6307692307692307,
#    'scout': 0.975609756097561,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.9761904761904762,
#    'gc': 0.9523809523809523,
#    'grype': 0.9761904761904762,
#    'scout': 0.9523809523809523,
#    'snyk': 0.6190476190476191,
#    'trivy': 0.9523809523809523},
#   'accuracy': {'clair': 0.9850746268656716,
#    'gc': 0.9701492537313433,
#    'grype': 0.6268656716417911,
#    'scout': 0.9552238805970149,
#    'snyk': 0.7611940298507462,
#    'trivy': 0.9701492537313433},
#   'f1': {'clair': 0.9879518072289156,
#    'gc': 0.975609756097561,
#    'grype': 0.7663551401869158,
#    'scout': 0.963855421686747,
#    'snyk': 0.7647058823529412,
#    'trivy': 0.975609756097561}},
#  {'tag': 'platformengineering/gcp-resource:0.24.0',
#   'tp': {'clair': 0, 'gc': 0, 'grype': 18, 'scout': 0, 'snyk': 0, 'trivy': 18},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 6, 'scout': 0, 'snyk': 0, 'trivy': 11},
#   'fn': {'clair': 18,
#    'gc': 18,
#    'grype': 0,
#    'scout': 18,
#    'snyk': 18,
#    'trivy': 0},
#   'tn': {'clair': 17,
#    'gc': 17,
#    'grype': 11,
#    'scout': 17,
#    'snyk': 17,
#    'trivy': 6},
#   'precision': {'clair': 1,
#    'gc': 1,
#    'grype': 0.75,
#    'scout': 1,
#    'snyk': 1,
#    'trivy': 0.6206896551724138},
#   'recall': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': 1.0,
#    'scout': 0.0,
#    'snyk': 0.0,
#    'trivy': 1.0},
#   'accuracy': {'clair': 0.4857142857142857,
#    'gc': 0.4857142857142857,
#    'grype': 0.8285714285714286,
#    'scout': 0.4857142857142857,
#    'snyk': 0.4857142857142857,
#    'trivy': 0.6857142857142857},
#   'f1': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': 0.8571428571428571,
#    'scout': 0.0,
#    'snyk': 0.0,
#    'trivy': 0.7659574468085107}},
#  {'tag': 'bitnami/kubeapps-asset-syncer:2.9.0-debian-11-r19',
#   'tp': {'clair': 5,
#    'gc': 15,
#    'grype': 20,
#    'scout': 20,
#    'snyk': 9,
#    'trivy': 15},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 15, 'gc': 5, 'grype': 0, 'scout': 0, 'snyk': 11, 'trivy': 5},
#   'tn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.25,
#    'gc': 0.75,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.45,
#    'trivy': 0.75},
#   'accuracy': {'clair': 0.25,
#    'gc': 0.75,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.45,
#    'trivy': 0.75},
#   'f1': {'clair': 0.4,
#    'gc': 0.8571428571428571,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.6206896551724138,
#    'trivy': 0.8571428571428571}},
#  {'tag': 'typositoire/concourse-helm3-resource:v1.14.0',
#   'tp': {'clair': 35,
#    'gc': 171,
#    'grype': 184,
#    'scout': 167,
#    'snyk': 47,
#    'trivy': 103},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 57, 'scout': 9, 'snyk': 2, 'trivy': 0},
#   'fn': {'clair': 149,
#    'gc': 13,
#    'grype': 0,
#    'scout': 17,
#    'snyk': 137,
#    'trivy': 81},
#   'tn': {'clair': 68,
#    'gc': 69,
#    'grype': 12,
#    'scout': 60,
#    'snyk': 67,
#    'trivy': 69},
#   'precision': {'clair': 0.9722222222222222,
#    'gc': 1.0,
#    'grype': 0.7634854771784232,
#    'scout': 0.9488636363636364,
#    'snyk': 0.9591836734693877,
#    'trivy': 1.0},
#   'recall': {'clair': 0.19021739130434784,
#    'gc': 0.9293478260869565,
#    'grype': 1.0,
#    'scout': 0.907608695652174,
#    'snyk': 0.2554347826086957,
#    'trivy': 0.5597826086956522},
#   'accuracy': {'clair': 0.40711462450592883,
#    'gc': 0.9486166007905138,
#    'grype': 0.7747035573122529,
#    'scout': 0.8972332015810277,
#    'snyk': 0.4505928853754941,
#    'trivy': 0.6798418972332015},
#   'f1': {'clair': 0.31818181818181823,
#    'gc': 0.9633802816901409,
#    'grype': 0.8658823529411764,
#    'scout': 0.9277777777777778,
#    'snyk': 0.4034334763948498,
#    'trivy': 0.7177700348432056}},
#  {'tag': 'bitnami/matomo:4.1.1-debian-10-r32',
#   'tp': {'clair': 556,
#    'gc': 544,
#    'grype': 572,
#    'scout': 421,
#    'snyk': 556,
#    'trivy': 556},
#   'fp': {'clair': 0,
#    'gc': 72,
#    'grype': 45,
#    'scout': 12,
#    'snyk': 0,
#    'trivy': 0},
#   'fn': {'clair': 16,
#    'gc': 28,
#    'grype': 0,
#    'scout': 151,
#    'snyk': 16,
#    'trivy': 16},
#   'tn': {'clair': 129,
#    'gc': 57,
#    'grype': 84,
#    'scout': 117,
#    'snyk': 129,
#    'trivy': 129},
#   'precision': {'clair': 1.0,
#    'gc': 0.8831168831168831,
#    'grype': 0.9270664505672609,
#    'scout': 0.9722863741339491,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.972027972027972,
#    'gc': 0.951048951048951,
#    'grype': 1.0,
#    'scout': 0.736013986013986,
#    'snyk': 0.972027972027972,
#    'trivy': 0.972027972027972},
#   'accuracy': {'clair': 0.9771754636233951,
#    'gc': 0.8573466476462197,
#    'grype': 0.9358059914407989,
#    'scout': 0.7674750356633381,
#    'snyk': 0.9771754636233951,
#    'trivy': 0.9771754636233951},
#   'f1': {'clair': 0.9858156028368793,
#    'gc': 0.9158249158249158,
#    'grype': 0.9621530698065601,
#    'scout': 0.8378109452736319,
#    'snyk': 0.9858156028368793,
#    'trivy': 0.9858156028368793}},
#  {'tag': 'blackfire/blackfire:2.4.2',
#   'tp': {'clair': 55,
#    'gc': 130,
#    'grype': 137,
#    'scout': 125,
#    'snyk': 64,
#    'trivy': 72},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 20, 'scout': 6, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 82,
#    'gc': 7,
#    'grype': 0,
#    'scout': 12,
#    'snyk': 73,
#    'trivy': 65},
#   'tn': {'clair': 26,
#    'gc': 27,
#    'grype': 7,
#    'scout': 21,
#    'snyk': 27,
#    'trivy': 27},
#   'precision': {'clair': 0.9821428571428571,
#    'gc': 1.0,
#    'grype': 0.8726114649681529,
#    'scout': 0.9541984732824428,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.40145985401459855,
#    'gc': 0.948905109489051,
#    'grype': 1.0,
#    'scout': 0.9124087591240876,
#    'snyk': 0.46715328467153283,
#    'trivy': 0.5255474452554745},
#   'accuracy': {'clair': 0.49390243902439024,
#    'gc': 0.9573170731707317,
#    'grype': 0.8780487804878049,
#    'scout': 0.8902439024390244,
#    'snyk': 0.5548780487804879,
#    'trivy': 0.6036585365853658},
#   'f1': {'clair': 0.5699481865284974,
#    'gc': 0.9737827715355805,
#    'grype': 0.9319727891156463,
#    'scout': 0.9328358208955224,
#    'snyk': 0.6368159203980099,
#    'trivy': 0.6889952153110048}},
#  {'tag': '18fgsa/s3-resource-simple:1.2.22',
#   'tp': {'clair': 101,
#    'gc': 307,
#    'grype': 101,
#    'scout': 352,
#    'snyk': 100,
#    'trivy': 346},
#   'fp': {'clair': 23, 'gc': 0, 'grype': 0, 'scout': 2, 'snyk': 1, 'trivy': 8},
#   'fn': {'clair': 253,
#    'gc': 47,
#    'grype': 253,
#    'scout': 2,
#    'snyk': 254,
#    'trivy': 8},
#   'tn': {'clair': 11,
#    'gc': 34,
#    'grype': 34,
#    'scout': 32,
#    'snyk': 33,
#    'trivy': 26},
#   'precision': {'clair': 0.8145161290322581,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 0.9943502824858758,
#    'snyk': 0.9900990099009901,
#    'trivy': 0.9774011299435028},
#   'recall': {'clair': 0.2853107344632768,
#    'gc': 0.867231638418079,
#    'grype': 0.2853107344632768,
#    'scout': 0.9943502824858758,
#    'snyk': 0.2824858757062147,
#    'trivy': 0.9774011299435028},
#   'accuracy': {'clair': 0.28865979381443296,
#    'gc': 0.8788659793814433,
#    'grype': 0.3479381443298969,
#    'scout': 0.9896907216494846,
#    'snyk': 0.3427835051546392,
#    'trivy': 0.9587628865979382},
#   'f1': {'clair': 0.4225941422594143,
#    'gc': 0.928895612708018,
#    'grype': 0.44395604395604393,
#    'scout': 0.9943502824858758,
#    'snyk': 0.43956043956043955,
#    'trivy': 0.9774011299435028}},
#  {'tag': 'amazeeio/solr:7.7-21.4.0',
#   'tp': {'clair': 255,
#    'gc': 317,
#    'grype': 317,
#    'scout': 319,
#    'snyk': 257,
#    'trivy': 258},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 73, 'scout': 8, 'snyk': 10, 'trivy': 0},
#   'fn': {'clair': 88,
#    'gc': 26,
#    'grype': 26,
#    'scout': 24,
#    'snyk': 86,
#    'trivy': 85},
#   'tn': {'clair': 91,
#    'gc': 91,
#    'grype': 18,
#    'scout': 83,
#    'snyk': 81,
#    'trivy': 91},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.8128205128205128,
#    'scout': 0.9755351681957186,
#    'snyk': 0.9625468164794008,
#    'trivy': 1.0},
#   'recall': {'clair': 0.7434402332361516,
#    'gc': 0.924198250728863,
#    'grype': 0.924198250728863,
#    'scout': 0.9300291545189504,
#    'snyk': 0.749271137026239,
#    'trivy': 0.7521865889212828},
#   'accuracy': {'clair': 0.7972350230414746,
#    'gc': 0.9400921658986175,
#    'grype': 0.771889400921659,
#    'scout': 0.9262672811059908,
#    'snyk': 0.7788018433179723,
#    'trivy': 0.804147465437788},
#   'f1': {'clair': 0.8528428093645485,
#    'gc': 0.9606060606060606,
#    'grype': 0.8649386084583902,
#    'scout': 0.9522388059701493,
#    'snyk': 0.8426229508196722,
#    'trivy': 0.8585690515806987}},
#  {'tag': 'linuxserver/pyload:amd64-version-d5123f76',
#   'tp': {'clair': 51,
#    'gc': 45,
#    'grype': 52,
#    'scout': 45,
#    'snyk': 0,
#    'trivy': 46},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 192, 'scout': 2, 'snyk': 0, 'trivy': 1},
#   'fn': {'clair': 1, 'gc': 7, 'grype': 0, 'scout': 7, 'snyk': 52, 'trivy': 6},
#   'tn': {'clair': 195,
#    'gc': 196,
#    'grype': 4,
#    'scout': 194,
#    'snyk': 196,
#    'trivy': 195},
#   'precision': {'clair': 0.9807692307692307,
#    'gc': 1.0,
#    'grype': 0.21311475409836064,
#    'scout': 0.9574468085106383,
#    'snyk': 1,
#    'trivy': 0.9787234042553191},
#   'recall': {'clair': 0.9807692307692307,
#    'gc': 0.8653846153846154,
#    'grype': 1.0,
#    'scout': 0.8653846153846154,
#    'snyk': 0.0,
#    'trivy': 0.8846153846153846},
#   'accuracy': {'clair': 0.9919354838709677,
#    'gc': 0.9717741935483871,
#    'grype': 0.22580645161290322,
#    'scout': 0.9637096774193549,
#    'snyk': 0.7903225806451613,
#    'trivy': 0.9717741935483871},
#   'f1': {'clair': 0.9807692307692307,
#    'gc': 0.9278350515463918,
#    'grype': 0.3513513513513513,
#    'scout': 0.9090909090909091,
#    'snyk': 0.0,
#    'trivy': 0.9292929292929293}},
#  {'tag': 'postgis/postgis:13-3.4-alpine',
#   'tp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 14, 'scout': 1, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 15,
#    'gc': 15,
#    'grype': 1,
#    'scout': 14,
#    'snyk': 15,
#    'trivy': 15},
#   'precision': {'clair': 1,
#    'gc': 1,
#    'grype': 0.0,
#    'scout': 0.0,
#    'snyk': 1,
#    'trivy': 1},
#   'recall': {'clair': 0,
#    'gc': 0,
#    'grype': 0,
#    'scout': 0,
#    'snyk': 0,
#    'trivy': 0},
#   'accuracy': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.06666666666666667,
#    'scout': 0.9333333333333333,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'f1': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': None,
#    'scout': None,
#    'snyk': 0.0,
#    'trivy': 0.0}},
#  {'tag': 'atlassian/pipelines-dvcstools:stg-stable',
#   'tp': {'clair': 14,
#    'gc': 15,
#    'grype': 14,
#    'scout': 15,
#    'snyk': 9,
#    'trivy': 9},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 84, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 1, 'gc': 0, 'grype': 1, 'scout': 0, 'snyk': 6, 'trivy': 6},
#   'tn': {'clair': 84,
#    'gc': 84,
#    'grype': 0,
#    'scout': 84,
#    'snyk': 84,
#    'trivy': 84},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.14285714285714285,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.9333333333333333,
#    'gc': 1.0,
#    'grype': 0.9333333333333333,
#    'scout': 1.0,
#    'snyk': 0.6,
#    'trivy': 0.6},
#   'accuracy': {'clair': 0.98989898989899,
#    'gc': 1.0,
#    'grype': 0.1414141414141414,
#    'scout': 1.0,
#    'snyk': 0.9393939393939394,
#    'trivy': 0.9393939393939394},
#   'f1': {'clair': 0.9655172413793104,
#    'gc': 1.0,
#    'grype': 0.24778761061946902,
#    'scout': 1.0,
#    'snyk': 0.7499999999999999,
#    'trivy': 0.7499999999999999}},
#  {'tag': 'pivotalservices/artifactory-resource:0.1',
#   'tp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 16, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 16,
#    'gc': 16,
#    'grype': 0,
#    'scout': 16,
#    'snyk': 16,
#    'trivy': 16},
#   'precision': {'clair': 1,
#    'gc': 1,
#    'grype': 0.0,
#    'scout': 1,
#    'snyk': 1,
#    'trivy': 1},
#   'recall': {'clair': 0,
#    'gc': 0,
#    'grype': 0,
#    'scout': 0,
#    'snyk': 0,
#    'trivy': 0},
#   'accuracy': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'f1': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': None,
#    'scout': 0.0,
#    'snyk': 0.0,
#    'trivy': 0.0}},
#  {'tag': 'linuxserver/nzbget:amd64-21.1.20220222',
#   'tp': {'clair': 14,
#    'gc': 12,
#    'grype': 60,
#    'scout': 13,
#    'snyk': 0,
#    'trivy': 52},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 28, 'scout': 0, 'snyk': 0, 'trivy': 19},
#   'fn': {'clair': 47,
#    'gc': 49,
#    'grype': 1,
#    'scout': 48,
#    'snyk': 61,
#    'trivy': 9},
#   'tn': {'clair': 47,
#    'gc': 47,
#    'grype': 19,
#    'scout': 47,
#    'snyk': 47,
#    'trivy': 28},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.6818181818181818,
#    'scout': 1.0,
#    'snyk': 1,
#    'trivy': 0.7323943661971831},
#   'recall': {'clair': 0.22950819672131148,
#    'gc': 0.19672131147540983,
#    'grype': 0.9836065573770492,
#    'scout': 0.21311475409836064,
#    'snyk': 0.0,
#    'trivy': 0.8524590163934426},
#   'accuracy': {'clair': 0.5648148148148148,
#    'gc': 0.5462962962962963,
#    'grype': 0.7314814814814815,
#    'scout': 0.5555555555555556,
#    'snyk': 0.4351851851851852,
#    'trivy': 0.7407407407407407},
#   'f1': {'clair': 0.37333333333333335,
#    'gc': 0.3287671232876712,
#    'grype': 0.8053691275167784,
#    'scout': 0.3513513513513513,
#    'snyk': 0.0,
#    'trivy': 0.787878787878788}},
#  {'tag': 'datadog/agent:7.38.0-rc.4-jmx',
#   'tp': {'clair': 197,
#    'gc': 243,
#    'grype': 263,
#    'scout': 252,
#    'snyk': 169,
#    'trivy': 216},
#   'fp': {'clair': 26, 'gc': 0, 'grype': 17, 'scout': 9, 'snyk': 4, 'trivy': 0},
#   'fn': {'clair': 68,
#    'gc': 22,
#    'grype': 2,
#    'scout': 13,
#    'snyk': 96,
#    'trivy': 49},
#   'tn': {'clair': 30,
#    'gc': 56,
#    'grype': 39,
#    'scout': 47,
#    'snyk': 52,
#    'trivy': 56},
#   'precision': {'clair': 0.8834080717488789,
#    'gc': 1.0,
#    'grype': 0.9392857142857143,
#    'scout': 0.9655172413793104,
#    'snyk': 0.976878612716763,
#    'trivy': 1.0},
#   'recall': {'clair': 0.7433962264150943,
#    'gc': 0.9169811320754717,
#    'grype': 0.9924528301886792,
#    'scout': 0.9509433962264151,
#    'snyk': 0.6377358490566037,
#    'trivy': 0.8150943396226416},
#   'accuracy': {'clair': 0.7071651090342679,
#    'gc': 0.9314641744548287,
#    'grype': 0.940809968847352,
#    'scout': 0.9314641744548287,
#    'snyk': 0.6884735202492211,
#    'trivy': 0.8473520249221184},
#   'f1': {'clair': 0.8073770491803279,
#    'gc': 0.9566929133858267,
#    'grype': 0.965137614678899,
#    'scout': 0.9581749049429659,
#    'snyk': 0.771689497716895,
#    'trivy': 0.8981288981288982}},
#  {'tag': 'statping/statping:v0.90.63',
#   'tp': {'clair': 48,
#    'gc': 134,
#    'grype': 144,
#    'scout': 128,
#    'snyk': 59,
#    'trivy': 72},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 37, 'scout': 8, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 96,
#    'gc': 10,
#    'grype': 0,
#    'scout': 16,
#    'snyk': 85,
#    'trivy': 72},
#   'tn': {'clair': 45,
#    'gc': 46,
#    'grype': 9,
#    'scout': 38,
#    'snyk': 46,
#    'trivy': 46},
#   'precision': {'clair': 0.9795918367346939,
#    'gc': 1.0,
#    'grype': 0.7955801104972375,
#    'scout': 0.9411764705882353,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.3333333333333333,
#    'gc': 0.9305555555555556,
#    'grype': 1.0,
#    'scout': 0.8888888888888888,
#    'snyk': 0.4097222222222222,
#    'trivy': 0.5},
#   'accuracy': {'clair': 0.48947368421052634,
#    'gc': 0.9473684210526315,
#    'grype': 0.8052631578947368,
#    'scout': 0.8736842105263158,
#    'snyk': 0.5526315789473685,
#    'trivy': 0.6210526315789474},
#   'f1': {'clair': 0.49740932642487046,
#    'gc': 0.9640287769784173,
#    'grype': 0.8861538461538462,
#    'scout': 0.9142857142857143,
#    'snyk': 0.5812807881773399,
#    'trivy': 0.6666666666666666}},
#  {'tag': 'yandex/clickhouse-server:21.10.3',
#   'tp': {'clair': 104,
#    'gc': 97,
#    'grype': 103,
#    'scout': 103,
#    'snyk': 104,
#    'trivy': 103},
#   'fp': {'clair': 44, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 1, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 7, 'grype': 1, 'scout': 1, 'snyk': 0, 'trivy': 1},
#   'tn': {'clair': 1,
#    'gc': 45,
#    'grype': 45,
#    'scout': 45,
#    'snyk': 44,
#    'trivy': 45},
#   'precision': {'clair': 0.7027027027027027,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.9904761904761905,
#    'trivy': 1.0},
#   'recall': {'clair': 1.0,
#    'gc': 0.9326923076923077,
#    'grype': 0.9903846153846154,
#    'scout': 0.9903846153846154,
#    'snyk': 1.0,
#    'trivy': 0.9903846153846154},
#   'accuracy': {'clair': 0.7046979865771812,
#    'gc': 0.9530201342281879,
#    'grype': 0.9932885906040269,
#    'scout': 0.9932885906040269,
#    'snyk': 0.9932885906040269,
#    'trivy': 0.9932885906040269},
#   'f1': {'clair': 0.8253968253968255,
#    'gc': 0.9651741293532339,
#    'grype': 0.9951690821256038,
#    'scout': 0.9951690821256038,
#    'snyk': 0.9952153110047847,
#    'trivy': 0.9951690821256038}},
#  {'tag': 'rancher/rke2-runtime:v1.27.7-rc4-rke2r1',
#   'tp': {'clair': 13,
#    'gc': 48,
#    'grype': 48,
#    'scout': 25,
#    'snyk': 6,
#    'trivy': 25},
#   'fp': {'clair': 0, 'gc': 1, 'grype': 9, 'scout': 2, 'snyk': 2, 'trivy': 0},
#   'fn': {'clair': 35,
#    'gc': 0,
#    'grype': 0,
#    'scout': 23,
#    'snyk': 42,
#    'trivy': 23},
#   'tn': {'clair': 14,
#    'gc': 13,
#    'grype': 5,
#    'scout': 12,
#    'snyk': 12,
#    'trivy': 14},
#   'precision': {'clair': 1.0,
#    'gc': 0.9795918367346939,
#    'grype': 0.8421052631578947,
#    'scout': 0.9259259259259259,
#    'snyk': 0.75,
#    'trivy': 1.0},
#   'recall': {'clair': 0.2708333333333333,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 0.5208333333333334,
#    'snyk': 0.125,
#    'trivy': 0.5208333333333334},
#   'accuracy': {'clair': 0.43548387096774194,
#    'gc': 0.9838709677419355,
#    'grype': 0.8548387096774194,
#    'scout': 0.5967741935483871,
#    'snyk': 0.2903225806451613,
#    'trivy': 0.6290322580645161},
#   'f1': {'clair': 0.4262295081967213,
#    'gc': 0.9896907216494846,
#    'grype': 0.9142857142857143,
#    'scout': 0.6666666666666667,
#    'snyk': 0.21428571428571427,
#    'trivy': 0.684931506849315}},
#  {'tag': 'vito/oci-build-task:master',
#   'tp': {'clair': 51,
#    'gc': 147,
#    'grype': 158,
#    'scout': 140,
#    'snyk': 61,
#    'trivy': 82},
#   'fp': {'clair': 2, 'gc': 2, 'grype': 31, 'scout': 9, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 108,
#    'gc': 12,
#    'grype': 1,
#    'scout': 19,
#    'snyk': 98,
#    'trivy': 77},
#   'tn': {'clair': 42,
#    'gc': 42,
#    'grype': 13,
#    'scout': 35,
#    'snyk': 44,
#    'trivy': 44},
#   'precision': {'clair': 0.9622641509433962,
#    'gc': 0.9865771812080537,
#    'grype': 0.8359788359788359,
#    'scout': 0.9395973154362416,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.32075471698113206,
#    'gc': 0.9245283018867925,
#    'grype': 0.9937106918238994,
#    'scout': 0.8805031446540881,
#    'snyk': 0.3836477987421384,
#    'trivy': 0.5157232704402516},
#   'accuracy': {'clair': 0.458128078817734,
#    'gc': 0.9310344827586207,
#    'grype': 0.8423645320197044,
#    'scout': 0.8620689655172413,
#    'snyk': 0.5172413793103449,
#    'trivy': 0.6206896551724138},
#   'f1': {'clair': 0.4811320754716982,
#    'gc': 0.9545454545454546,
#    'grype': 0.9080459770114943,
#    'scout': 0.9090909090909091,
#    'snyk': 0.5545454545454546,
#    'trivy': 0.6804979253112033}},
#  {'tag': 'armory/echo:2.9.0-575b828-acca50a-edge530',
#   'tp': {'clair': 244,
#    'gc': 242,
#    'grype': 238,
#    'scout': 252,
#    'snyk': 249,
#    'trivy': 244},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 56, 'scout': 7, 'snyk': 15, 'trivy': 0},
#   'fn': {'clair': 15,
#    'gc': 17,
#    'grype': 21,
#    'scout': 7,
#    'snyk': 10,
#    'trivy': 15},
#   'tn': {'clair': 78,
#    'gc': 78,
#    'grype': 22,
#    'scout': 71,
#    'snyk': 63,
#    'trivy': 78},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.8095238095238095,
#    'scout': 0.972972972972973,
#    'snyk': 0.9431818181818182,
#    'trivy': 1.0},
#   'recall': {'clair': 0.9420849420849421,
#    'gc': 0.9343629343629344,
#    'grype': 0.918918918918919,
#    'scout': 0.972972972972973,
#    'snyk': 0.9613899613899614,
#    'trivy': 0.9420849420849421},
#   'accuracy': {'clair': 0.9554896142433235,
#    'gc': 0.9495548961424333,
#    'grype': 0.771513353115727,
#    'scout': 0.9584569732937686,
#    'snyk': 0.9258160237388724,
#    'trivy': 0.9554896142433235},
#   'f1': {'clair': 0.970178926441352,
#    'gc': 0.9660678642714572,
#    'grype': 0.860759493670886,
#    'scout': 0.972972972972973,
#    'snyk': 0.9521988527724665,
#    'trivy': 0.970178926441352}},
#  {'tag': 'istio/mixer:1.6.8',
#   'tp': {'clair': 242,
#    'gc': 819,
#    'grype': 849,
#    'scout': 660,
#    'snyk': 239,
#    'trivy': 596},
#   'fp': {'clair': 55,
#    'gc': 8,
#    'grype': 467,
#    'scout': 7,
#    'snyk': 1,
#    'trivy': 0},
#   'fn': {'clair': 614,
#    'gc': 37,
#    'grype': 7,
#    'scout': 196,
#    'snyk': 617,
#    'trivy': 260},
#   'tn': {'clair': 483,
#    'gc': 530,
#    'grype': 71,
#    'scout': 531,
#    'snyk': 537,
#    'trivy': 538},
#   'precision': {'clair': 0.8148148148148148,
#    'gc': 0.9903264812575574,
#    'grype': 0.6451367781155015,
#    'scout': 0.9895052473763118,
#    'snyk': 0.9958333333333333,
#    'trivy': 1.0},
#   'recall': {'clair': 0.2827102803738318,
#    'gc': 0.9567757009345794,
#    'grype': 0.991822429906542,
#    'scout': 0.7710280373831776,
#    'snyk': 0.27920560747663553,
#    'trivy': 0.6962616822429907},
#   'accuracy': {'clair': 0.5200860832137734,
#    'gc': 0.9677187948350072,
#    'grype': 0.6599713055954088,
#    'scout': 0.8543758967001435,
#    'snyk': 0.5566714490674318,
#    'trivy': 0.8134863701578192},
#   'f1': {'clair': 0.419774501300954,
#    'gc': 0.9732620320855615,
#    'grype': 0.7817679558011049,
#    'scout': 0.8667104399212082,
#    'snyk': 0.43613138686131386,
#    'trivy': 0.8209366391184573}},
#  {'tag': 'cfbuildpacks/cron-resource:latest',
#   'tp': {'clair': 0,
#    'gc': 587,
#    'grype': 159,
#    'scout': 11,
#    'snyk': 151,
#    'trivy': 527},
#   'fp': {'clair': 0,
#    'gc': 116,
#    'grype': 19,
#    'scout': 3,
#    'snyk': 1,
#    'trivy': 2},
#   'fn': {'clair': 589,
#    'gc': 2,
#    'grype': 430,
#    'scout': 578,
#    'snyk': 438,
#    'trivy': 62},
#   'tn': {'clair': 141,
#    'gc': 25,
#    'grype': 122,
#    'scout': 138,
#    'snyk': 140,
#    'trivy': 139},
#   'precision': {'clair': 1,
#    'gc': 0.8349928876244666,
#    'grype': 0.8932584269662921,
#    'scout': 0.7857142857142857,
#    'snyk': 0.993421052631579,
#    'trivy': 0.996219281663516},
#   'recall': {'clair': 0.0,
#    'gc': 0.9966044142614601,
#    'grype': 0.2699490662139219,
#    'scout': 0.01867572156196944,
#    'snyk': 0.2563667232597623,
#    'trivy': 0.8947368421052632},
#   'accuracy': {'clair': 0.19315068493150686,
#    'gc': 0.8383561643835616,
#    'grype': 0.38493150684931504,
#    'scout': 0.20410958904109588,
#    'snyk': 0.39863013698630134,
#    'trivy': 0.9123287671232877},
#   'f1': {'clair': 0.0,
#    'gc': 0.9086687306501547,
#    'grype': 0.41460234680573665,
#    'scout': 0.03648424543946932,
#    'snyk': 0.4075573549257759,
#    'trivy': 0.9427549194991054}},
#  {'tag': 'jaegertracing/jaeger-operator:1.55',
#   'tp': {'clair': 0,
#    'gc': 1,
#    'grype': 158,
#    'scout': 53,
#    'snyk': 159,
#    'trivy': 1},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 1, 'scout': 49, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 159,
#    'gc': 158,
#    'grype': 1,
#    'scout': 106,
#    'snyk': 0,
#    'trivy': 158},
#   'tn': {'clair': 50,
#    'gc': 50,
#    'grype': 49,
#    'scout': 1,
#    'snyk': 50,
#    'trivy': 50},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 0.9937106918238994,
#    'scout': 0.5196078431372549,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.006289308176100629,
#    'grype': 0.9937106918238994,
#    'scout': 0.3333333333333333,
#    'snyk': 1.0,
#    'trivy': 0.006289308176100629},
#   'accuracy': {'clair': 0.23923444976076555,
#    'gc': 0.24401913875598086,
#    'grype': 0.9904306220095693,
#    'scout': 0.2583732057416268,
#    'snyk': 1.0,
#    'trivy': 0.24401913875598086},
#   'f1': {'clair': 0.0,
#    'gc': 0.0125,
#    'grype': 0.9937106918238994,
#    'scout': 0.40613026819923365,
#    'snyk': 1.0,
#    'trivy': 0.0125}},
#  {'tag': 'dperson/torproxy:latest',
#   'tp': {'clair': 72,
#    'gc': 70,
#    'grype': 72,
#    'scout': 72,
#    'snyk': 72,
#    'trivy': 72},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 41, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 2, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 41,
#    'gc': 41,
#    'grype': 0,
#    'scout': 41,
#    'snyk': 41,
#    'trivy': 41},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.6371681415929203,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 1.0,
#    'gc': 0.9722222222222222,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'accuracy': {'clair': 1.0,
#    'gc': 0.9823008849557522,
#    'grype': 0.6371681415929203,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'f1': {'clair': 1.0,
#    'gc': 0.9859154929577464,
#    'grype': 0.7783783783783783,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0}},
#  {'tag': 'pcfseceng/email-resource:1.0.20-91a96e53af36568910b8cbf21944ede2d9f36fab',
#   'tp': {'clair': 0,
#    'gc': 29,
#    'grype': 40,
#    'scout': 34,
#    'snyk': 0,
#    'trivy': 0},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 18, 'scout': 1, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 40,
#    'gc': 11,
#    'grype': 0,
#    'scout': 6,
#    'snyk': 40,
#    'trivy': 40},
#   'tn': {'clair': 19,
#    'gc': 19,
#    'grype': 1,
#    'scout': 18,
#    'snyk': 19,
#    'trivy': 19},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 0.6896551724137931,
#    'scout': 0.9714285714285714,
#    'snyk': 1,
#    'trivy': 1},
#   'recall': {'clair': 0.0,
#    'gc': 0.725,
#    'grype': 1.0,
#    'scout': 0.85,
#    'snyk': 0.0,
#    'trivy': 0.0},
#   'accuracy': {'clair': 0.3220338983050847,
#    'gc': 0.8135593220338984,
#    'grype': 0.6949152542372882,
#    'scout': 0.8813559322033898,
#    'snyk': 0.3220338983050847,
#    'trivy': 0.3220338983050847},
#   'f1': {'clair': 0.0,
#    'gc': 0.8405797101449275,
#    'grype': 0.8163265306122449,
#    'scout': 0.9066666666666667,
#    'snyk': 0.0,
#    'trivy': 0.0}},
#  {'tag': 'amazon/aws-cli:2.15.1',
#   'tp': {'clair': 0,
#    'gc': 0,
#    'grype': 19,
#    'scout': 17,
#    'snyk': 20,
#    'trivy': 17},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 2, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 20, 'gc': 20, 'grype': 1, 'scout': 3, 'snyk': 0, 'trivy': 3},
#   'tn': {'clair': 2, 'gc': 2, 'grype': 0, 'scout': 2, 'snyk': 2, 'trivy': 2},
#   'precision': {'clair': 1,
#    'gc': 1,
#    'grype': 0.9047619047619048,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': 0.95,
#    'scout': 0.85,
#    'snyk': 1.0,
#    'trivy': 0.85},
#   'accuracy': {'clair': 0.09090909090909091,
#    'gc': 0.09090909090909091,
#    'grype': 0.8636363636363636,
#    'scout': 0.8636363636363636,
#    'snyk': 1.0,
#    'trivy': 0.8636363636363636},
#   'f1': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': 0.9268292682926829,
#    'scout': 0.9189189189189189,
#    'snyk': 1.0,
#    'trivy': 0.9189189189189189}},
#  {'tag': 'kope/protokube:latest',
#   'tp': {'clair': 0,
#    'gc': 176,
#    'grype': 176,
#    'scout': 0,
#    'snyk': 178,
#    'trivy': 117},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 1, 'trivy': 0},
#   'fn': {'clair': 178,
#    'gc': 2,
#    'grype': 2,
#    'scout': 178,
#    'snyk': 0,
#    'trivy': 61},
#   'tn': {'clair': 1, 'gc': 1, 'grype': 1, 'scout': 1, 'snyk': 0, 'trivy': 1},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1,
#    'snyk': 0.994413407821229,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.9887640449438202,
#    'grype': 0.9887640449438202,
#    'scout': 0.0,
#    'snyk': 1.0,
#    'trivy': 0.6573033707865169},
#   'accuracy': {'clair': 0.00558659217877095,
#    'gc': 0.9888268156424581,
#    'grype': 0.9888268156424581,
#    'scout': 0.00558659217877095,
#    'snyk': 0.994413407821229,
#    'trivy': 0.659217877094972},
#   'f1': {'clair': 0.0,
#    'gc': 0.9943502824858756,
#    'grype': 0.9943502824858756,
#    'scout': 0.0,
#    'snyk': 0.9971988795518207,
#    'trivy': 0.7932203389830509}},
#  {'tag': 'anchorfree/afmon:master',
#   'tp': {'clair': 18,
#    'gc': 17,
#    'grype': 18,
#    'scout': 18,
#    'snyk': 18,
#    'trivy': 18},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 46, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 1, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 46,
#    'gc': 46,
#    'grype': 0,
#    'scout': 46,
#    'snyk': 46,
#    'trivy': 46},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.28125,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 1.0,
#    'gc': 0.9444444444444444,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'accuracy': {'clair': 1.0,
#    'gc': 0.984375,
#    'grype': 0.28125,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'f1': {'clair': 1.0,
#    'gc': 0.9714285714285714,
#    'grype': 0.43902439024390244,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0}},
#  {'tag': 'jorrite/az-storage-backup:4.0.2',
#   'tp': {'clair': 107,
#    'gc': 183,
#    'grype': 201,
#    'scout': 178,
#    'snyk': 78,
#    'trivy': 121},
#   'fp': {'clair': 2,
#    'gc': 0,
#    'grype': 164,
#    'scout': 10,
#    'snyk': 0,
#    'trivy': 0},
#   'fn': {'clair': 95,
#    'gc': 19,
#    'grype': 1,
#    'scout': 24,
#    'snyk': 124,
#    'trivy': 81},
#   'tn': {'clair': 174,
#    'gc': 176,
#    'grype': 12,
#    'scout': 166,
#    'snyk': 176,
#    'trivy': 176},
#   'precision': {'clair': 0.981651376146789,
#    'gc': 1.0,
#    'grype': 0.5506849315068493,
#    'scout': 0.9468085106382979,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.5297029702970297,
#    'gc': 0.905940594059406,
#    'grype': 0.995049504950495,
#    'scout': 0.8811881188118812,
#    'snyk': 0.38613861386138615,
#    'trivy': 0.599009900990099},
#   'accuracy': {'clair': 0.7433862433862434,
#    'gc': 0.9497354497354498,
#    'grype': 0.5634920634920635,
#    'scout': 0.91005291005291,
#    'snyk': 0.671957671957672,
#    'trivy': 0.7857142857142857},
#   'f1': {'clair': 0.6881028938906751,
#    'gc': 0.9506493506493507,
#    'grype': 0.708994708994709,
#    'scout': 0.9128205128205128,
#    'snyk': 0.5571428571428572,
#    'trivy': 0.7492260061919503}},
#  {'tag': 'rancher/lb-service-haproxy:v0.9.3',
#   'tp': {'clair': 586,
#    'gc': 870,
#    'grype': 507,
#    'scout': 582,
#    'snyk': 543,
#    'trivy': 582},
#   'fp': {'clair': 54,
#    'gc': 308,
#    'grype': 171,
#    'scout': 0,
#    'snyk': 1,
#    'trivy': 0},
#   'fn': {'clair': 357,
#    'gc': 73,
#    'grype': 436,
#    'scout': 361,
#    'snyk': 400,
#    'trivy': 361},
#   'tn': {'clair': 480,
#    'gc': 226,
#    'grype': 363,
#    'scout': 534,
#    'snyk': 533,
#    'trivy': 534},
#   'precision': {'clair': 0.915625,
#    'gc': 0.7385398981324278,
#    'grype': 0.7477876106194691,
#    'scout': 1.0,
#    'snyk': 0.9981617647058824,
#    'trivy': 1.0},
#   'recall': {'clair': 0.6214209968186638,
#    'gc': 0.9225874867444327,
#    'grype': 0.5376458112407211,
#    'scout': 0.6171792152704135,
#    'snyk': 0.5758218451749735,
#    'trivy': 0.6171792152704135},
#   'accuracy': {'clair': 0.7217332430602573,
#    'gc': 0.7420446851726472,
#    'grype': 0.5890318212593094,
#    'scout': 0.7555856465809072,
#    'snyk': 0.7285037237643873,
#    'trivy': 0.7555856465809072},
#   'f1': {'clair': 0.7403663929248263,
#    'gc': 0.8203677510608204,
#    'grype': 0.6255397902529303,
#    'scout': 0.7632786885245901,
#    'snyk': 0.7303295225285811,
#    'trivy': 0.7632786885245901}},
#  {'tag': 'oryd/keto:v0.12.0-alpha.0-amd64-distroless',
#   'tp': {'clair': 0, 'gc': 9, 'grype': 14, 'scout': 14, 'snyk': 3, 'trivy': 9},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 14, 'gc': 5, 'grype': 0, 'scout': 0, 'snyk': 11, 'trivy': 5},
#   'tn': {'clair': 0, 'gc': 1, 'grype': 1, 'scout': 1, 'snyk': 1, 'trivy': 1},
#   'precision': {'clair': 0.0,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.6428571428571429,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.21428571428571427,
#    'trivy': 0.6428571428571429},
#   'accuracy': {'clair': 0.0,
#    'gc': 0.6666666666666666,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.26666666666666666,
#    'trivy': 0.6666666666666666},
#   'f1': {'clair': None,
#    'gc': 0.782608695652174,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.35294117647058826,
#    'trivy': 0.782608695652174}},
#  {'tag': 'circleci/node:17.0-bullseye',
#   'tp': {'clair': 683,
#    'gc': 1799,
#    'grype': 697,
#    'scout': 495,
#    'snyk': 690,
#    'trivy': 1812},
#   'fp': {'clair': 0,
#    'gc': 72,
#    'grype': 1,
#    'scout': 1,
#    'snyk': 12,
#    'trivy': 20},
#   'fn': {'clair': 1135,
#    'gc': 19,
#    'grype': 1121,
#    'scout': 1323,
#    'snyk': 1128,
#    'trivy': 6},
#   'tn': {'clair': 106,
#    'gc': 34,
#    'grype': 105,
#    'scout': 105,
#    'snyk': 94,
#    'trivy': 86},
#   'precision': {'clair': 1.0,
#    'gc': 0.9615179048637092,
#    'grype': 0.998567335243553,
#    'scout': 0.9979838709677419,
#    'snyk': 0.9829059829059829,
#    'trivy': 0.9890829694323144},
#   'recall': {'clair': 0.3756875687568757,
#    'gc': 0.9895489548954896,
#    'grype': 0.3833883388338834,
#    'scout': 0.2722772277227723,
#    'snyk': 0.3795379537953795,
#    'trivy': 0.9966996699669967},
#   'accuracy': {'clair': 0.4100831600831601,
#    'gc': 0.9527027027027027,
#    'grype': 0.41683991683991684,
#    'scout': 0.31185031185031187,
#    'snyk': 0.4074844074844075,
#    'trivy': 0.9864864864864865},
#   'f1': {'clair': 0.5461815273890444,
#    'gc': 0.9753320683111953,
#    'grype': 0.5540540540540542,
#    'scout': 0.42783059636992227,
#    'snyk': 0.5476190476190477,
#    'trivy': 0.9928767123287671}},
#  {'tag': 'jippi/hashi-ui:pr-561',
#   'tp': {'clair': 38,
#    'gc': 114,
#    'grype': 123,
#    'scout': 108,
#    'snyk': 40,
#    'trivy': 39},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 43, 'scout': 8, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 86,
#    'gc': 10,
#    'grype': 1,
#    'scout': 16,
#    'snyk': 84,
#    'trivy': 85},
#   'tn': {'clair': 51,
#    'gc': 51,
#    'grype': 8,
#    'scout': 43,
#    'snyk': 51,
#    'trivy': 51},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.7409638554216867,
#    'scout': 0.9310344827586207,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.3064516129032258,
#    'gc': 0.9193548387096774,
#    'grype': 0.9919354838709677,
#    'scout': 0.8709677419354839,
#    'snyk': 0.3225806451612903,
#    'trivy': 0.31451612903225806},
#   'accuracy': {'clair': 0.5085714285714286,
#    'gc': 0.9428571428571428,
#    'grype': 0.7485714285714286,
#    'scout': 0.8628571428571429,
#    'snyk': 0.52,
#    'trivy': 0.5142857142857142},
#   'f1': {'clair': 0.46913580246913583,
#    'gc': 0.9579831932773109,
#    'grype': 0.8482758620689654,
#    'scout': 0.9,
#    'snyk': 0.4878048780487805,
#    'trivy': 0.4785276073619632}},
#  {'tag': 'getsentry/snuba:7961a60d74caeadef6bf2eef6d1ffbd4aaf5f316',
#   'tp': {'clair': 204,
#    'gc': 865,
#    'grype': 204,
#    'scout': 118,
#    'snyk': 201,
#    'trivy': 865},
#   'fp': {'clair': 0, 'gc': 6, 'grype': 8, 'scout': 3, 'snyk': 6, 'trivy': 0},
#   'fn': {'clair': 662,
#    'gc': 1,
#    'grype': 662,
#    'scout': 748,
#    'snyk': 665,
#    'trivy': 1},
#   'tn': {'clair': 23,
#    'gc': 17,
#    'grype': 15,
#    'scout': 20,
#    'snyk': 17,
#    'trivy': 23},
#   'precision': {'clair': 1.0,
#    'gc': 0.9931113662456946,
#    'grype': 0.9622641509433962,
#    'scout': 0.9752066115702479,
#    'snyk': 0.9710144927536232,
#    'trivy': 1.0},
#   'recall': {'clair': 0.23556581986143188,
#    'gc': 0.9988452655889145,
#    'grype': 0.23556581986143188,
#    'scout': 0.13625866050808313,
#    'snyk': 0.23210161662817552,
#    'trivy': 0.9988452655889145},
#   'accuracy': {'clair': 0.25534308211473566,
#    'gc': 0.9921259842519685,
#    'grype': 0.24634420697412823,
#    'scout': 0.15523059617547807,
#    'snyk': 0.2452193475815523,
#    'trivy': 0.9988751406074241},
#   'f1': {'clair': 0.3813084112149533,
#    'gc': 0.9959700633275763,
#    'grype': 0.37847866419294995,
#    'scout': 0.23910840932117525,
#    'snyk': 0.374650512581547,
#    'trivy': 0.999422299248989}},
#  {'tag': 'swce/keyval-resource:latest',
#   'tp': {'clair': 4, 'gc': 4, 'grype': 19, 'scout': 3, 'snyk': 4, 'trivy': 19},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 4, 'scout': 0, 'snyk': 0, 'trivy': 14},
#   'fn': {'clair': 15,
#    'gc': 15,
#    'grype': 0,
#    'scout': 16,
#    'snyk': 15,
#    'trivy': 0},
#   'tn': {'clair': 18,
#    'gc': 18,
#    'grype': 14,
#    'scout': 18,
#    'snyk': 18,
#    'trivy': 4},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.8260869565217391,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 0.5757575757575758},
#   'recall': {'clair': 0.21052631578947367,
#    'gc': 0.21052631578947367,
#    'grype': 1.0,
#    'scout': 0.15789473684210525,
#    'snyk': 0.21052631578947367,
#    'trivy': 1.0},
#   'accuracy': {'clair': 0.5945945945945946,
#    'gc': 0.5945945945945946,
#    'grype': 0.8918918918918919,
#    'scout': 0.5675675675675675,
#    'snyk': 0.5945945945945946,
#    'trivy': 0.6216216216216216},
#   'f1': {'clair': 0.34782608695652173,
#    'gc': 0.34782608695652173,
#    'grype': 0.9047619047619047,
#    'scout': 0.2727272727272727,
#    'snyk': 0.34782608695652173,
#    'trivy': 0.7307692307692308}},
#  {'tag': 'vaultwarden/server:testing',
#   'tp': {'clair': 59,
#    'gc': 271,
#    'grype': 61,
#    'scout': 35,
#    'snyk': 61,
#    'trivy': 271},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 303},
#   'fn': {'clair': 214,
#    'gc': 2,
#    'grype': 212,
#    'scout': 238,
#    'snyk': 212,
#    'trivy': 2},
#   'tn': {'clair': 303,
#    'gc': 303,
#    'grype': 303,
#    'scout': 303,
#    'snyk': 303,
#    'trivy': 0},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 0.4721254355400697},
#   'recall': {'clair': 0.21611721611721613,
#    'gc': 0.9926739926739927,
#    'grype': 0.22344322344322345,
#    'scout': 0.1282051282051282,
#    'snyk': 0.22344322344322345,
#    'trivy': 0.9926739926739927},
#   'accuracy': {'clair': 0.6284722222222222,
#    'gc': 0.9965277777777778,
#    'grype': 0.6319444444444444,
#    'scout': 0.5868055555555556,
#    'snyk': 0.6319444444444444,
#    'trivy': 0.4704861111111111},
#   'f1': {'clair': 0.35542168674698793,
#    'gc': 0.9963235294117647,
#    'grype': 0.3652694610778443,
#    'scout': 0.22727272727272727,
#    'snyk': 0.3652694610778443,
#    'trivy': 0.6399055489964581}},
#  {'tag': 'seabreeze/sbz-helloworld-sidecar:1.0-alpine',
#   'tp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 15, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 15,
#    'gc': 15,
#    'grype': 0,
#    'scout': 15,
#    'snyk': 15,
#    'trivy': 15},
#   'precision': {'clair': 1,
#    'gc': 1,
#    'grype': 0.0,
#    'scout': 1,
#    'snyk': 1,
#    'trivy': 1},
#   'recall': {'clair': 0,
#    'gc': 0,
#    'grype': 0,
#    'scout': 0,
#    'snyk': 0,
#    'trivy': 0},
#   'accuracy': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'f1': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': None,
#    'scout': 0.0,
#    'snyk': 0.0,
#    'trivy': 0.0}},
#  {'tag': 'linuxserver/code-server:4.23.0-ls205',
#   'tp': {'clair': 23,
#    'gc': 15,
#    'grype': 49,
#    'scout': 51,
#    'snyk': 25,
#    'trivy': 49},
#   'fp': {'clair': 16, 'gc': 0, 'grype': 1, 'scout': 0, 'snyk': 5, 'trivy': 0},
#   'fn': {'clair': 28,
#    'gc': 36,
#    'grype': 2,
#    'scout': 0,
#    'snyk': 26,
#    'trivy': 2},
#   'tn': {'clair': 6,
#    'gc': 22,
#    'grype': 21,
#    'scout': 22,
#    'snyk': 17,
#    'trivy': 22},
#   'precision': {'clair': 0.5897435897435898,
#    'gc': 1.0,
#    'grype': 0.98,
#    'scout': 1.0,
#    'snyk': 0.8333333333333334,
#    'trivy': 1.0},
#   'recall': {'clair': 0.45098039215686275,
#    'gc': 0.29411764705882354,
#    'grype': 0.9607843137254902,
#    'scout': 1.0,
#    'snyk': 0.49019607843137253,
#    'trivy': 0.9607843137254902},
#   'accuracy': {'clair': 0.3972602739726027,
#    'gc': 0.5068493150684932,
#    'grype': 0.958904109589041,
#    'scout': 1.0,
#    'snyk': 0.5753424657534246,
#    'trivy': 0.9726027397260274},
#   'f1': {'clair': 0.5111111111111111,
#    'gc': 0.45454545454545453,
#    'grype': 0.9702970297029702,
#    'scout': 1.0,
#    'snyk': 0.6172839506172839,
#    'trivy': 0.98}},
#  {'tag': 'aequitas/http-api-resource:latest',
#   'tp': {'clair': 906,
#    'gc': 1945,
#    'grype': 909,
#    'scout': 731,
#    'snyk': 894,
#    'trivy': 1957},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 3, 'scout': 3, 'snyk': 0, 'trivy': 17},
#   'fn': {'clair': 1059,
#    'gc': 20,
#    'grype': 1056,
#    'scout': 1234,
#    'snyk': 1071,
#    'trivy': 8},
#   'tn': {'clair': 23,
#    'gc': 23,
#    'grype': 20,
#    'scout': 20,
#    'snyk': 23,
#    'trivy': 6},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.9967105263157895,
#    'scout': 0.9959128065395095,
#    'snyk': 1.0,
#    'trivy': 0.9913880445795339},
#   'recall': {'clair': 0.46106870229007635,
#    'gc': 0.989821882951654,
#    'grype': 0.46259541984732827,
#    'scout': 0.37201017811704834,
#    'snyk': 0.4549618320610687,
#    'trivy': 0.9959287531806615},
#   'accuracy': {'clair': 0.46730382293762573,
#    'gc': 0.9899396378269618,
#    'grype': 0.46730382293762573,
#    'scout': 0.3777665995975855,
#    'snyk': 0.4612676056338028,
#    'trivy': 0.9874245472837022},
#   'f1': {'clair': 0.6311389759665622,
#    'gc': 0.9948849104859334,
#    'grype': 0.6319082377476538,
#    'scout': 0.5416821044831419,
#    'snyk': 0.6253934942287513,
#    'trivy': 0.9936532114749935}},
#  {'tag': 'linuxserver/ombi:amd64-4.2.7',
#   'tp': {'clair': 148,
#    'gc': 127,
#    'grype': 142,
#    'scout': 88,
#    'snyk': 138,
#    'trivy': 88},
#   'fp': {'clair': 32, 'gc': 0, 'grype': 30, 'scout': 0, 'snyk': 1, 'trivy': 0},
#   'fn': {'clair': 0,
#    'gc': 21,
#    'grype': 6,
#    'scout': 60,
#    'snyk': 10,
#    'trivy': 60},
#   'tn': {'clair': 31,
#    'gc': 63,
#    'grype': 33,
#    'scout': 63,
#    'snyk': 62,
#    'trivy': 63},
#   'precision': {'clair': 0.8222222222222222,
#    'gc': 1.0,
#    'grype': 0.8255813953488372,
#    'scout': 1.0,
#    'snyk': 0.9928057553956835,
#    'trivy': 1.0},
#   'recall': {'clair': 1.0,
#    'gc': 0.8581081081081081,
#    'grype': 0.9594594594594594,
#    'scout': 0.5945945945945946,
#    'snyk': 0.9324324324324325,
#    'trivy': 0.5945945945945946},
#   'accuracy': {'clair': 0.8483412322274881,
#    'gc': 0.9004739336492891,
#    'grype': 0.8293838862559242,
#    'scout': 0.7156398104265402,
#    'snyk': 0.9478672985781991,
#    'trivy': 0.7156398104265402},
#   'f1': {'clair': 0.9024390243902439,
#    'gc': 0.9236363636363636,
#    'grype': 0.8875000000000001,
#    'scout': 0.7457627118644068,
#    'snyk': 0.9616724738675959,
#    'trivy': 0.7457627118644068}},
#  {'tag': 'ruhmesmeile/php-nginx-static:develop',
#   'tp': {'clair': 1,
#    'gc': 1141,
#    'grype': 1024,
#    'scout': 2,
#    'snyk': 1030,
#    'trivy': 972},
#   'fp': {'clair': 0,
#    'gc': 118,
#    'grype': 54,
#    'scout': 0,
#    'snyk': 7,
#    'trivy': 1},
#   'fn': {'clair': 1348,
#    'gc': 208,
#    'grype': 325,
#    'scout': 1347,
#    'snyk': 319,
#    'trivy': 377},
# ...
#    'trivy': 0.7157712305025997}},
#  {'tag': 'circleci/docker-gc:2.0.1582-ff07771',
#   'tp': {'clair': 0, 'gc': 2, 'grype': 7, 'scout': 7, 'snyk': 1, 'trivy': 2},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 7, 'gc': 5, 'grype': 0, 'scout': 0, 'snyk': 6, 'trivy': 5},
#   'tn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.2857142857142857,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.14285714285714285,
#    'trivy': 0.2857142857142857},
#   'accuracy': {'clair': 0.0,
#    'gc': 0.2857142857142857,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.14285714285714285,
#    'trivy': 0.2857142857142857},
#   'f1': {'clair': 0.0,
#    'gc': 0.4444444444444445,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.25,
#    'trivy': 0.4444444444444445}},
#  {'tag': 'drone/drone-runner-docker:1.8.2',
#   'tp': {'clair': 13,
#    'gc': 95,
#    'grype': 101,
#    'scout': 91,
#    'snyk': 19,
#    'trivy': 52},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 2, 'scout': 7, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 88,
#    'gc': 6,
#    'grype': 0,
#    'scout': 10,
#    'snyk': 82,
#    'trivy': 49},
#   'tn': {'clair': 9,
#    'gc': 10,
#    'grype': 8,
#    'scout': 3,
#    'snyk': 10,
#    'trivy': 10},
#   'precision': {'clair': 0.9285714285714286,
#    'gc': 1.0,
#    'grype': 0.9805825242718447,
#    'scout': 0.9285714285714286,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.12871287128712872,
#    'gc': 0.9405940594059405,
#    'grype': 1.0,
#    'scout': 0.900990099009901,
#    'snyk': 0.18811881188118812,
#    'trivy': 0.5148514851485149},
#   'accuracy': {'clair': 0.1981981981981982,
#    'gc': 0.9459459459459459,
#    'grype': 0.9819819819819819,
#    'scout': 0.8468468468468469,
#    'snyk': 0.26126126126126126,
#    'trivy': 0.5585585585585585},
#   'f1': {'clair': 0.22608695652173916,
#    'gc': 0.9693877551020408,
#    'grype': 0.9901960784313726,
#    'scout': 0.914572864321608,
#    'snyk': 0.3166666666666667,
#    'trivy': 0.6797385620915033}},
#  {'tag': 'amazon/cloudwatch-agent:1.247359.1b252618',
#   'tp': {'clair': 9,
#    'gc': 34,
#    'grype': 42,
#    'scout': 36,
#    'snyk': 9,
#    'trivy': 23},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 4, 'snyk': 1, 'trivy': 0},
#   'fn': {'clair': 33,
#    'gc': 8,
#    'grype': 0,
#    'scout': 6,
#    'snyk': 33,
#    'trivy': 19},
#   'tn': {'clair': 5, 'gc': 5, 'grype': 5, 'scout': 1, 'snyk': 4, 'trivy': 5},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 0.9,
#    'snyk': 0.9,
#    'trivy': 1.0},
#   'recall': {'clair': 0.21428571428571427,
#    'gc': 0.8095238095238095,
#    'grype': 1.0,
#    'scout': 0.8571428571428571,
#    'snyk': 0.21428571428571427,
#    'trivy': 0.5476190476190477},
#   'accuracy': {'clair': 0.2978723404255319,
#    'gc': 0.8297872340425532,
#    'grype': 1.0,
#    'scout': 0.7872340425531915,
#    'snyk': 0.2765957446808511,
#    'trivy': 0.5957446808510638},
#   'f1': {'clair': 0.35294117647058826,
#    'gc': 0.8947368421052632,
#    'grype': 1.0,
#    'scout': 0.8780487804878048,
#    'snyk': 0.3461538461538461,
#    'trivy': 0.7076923076923077}},
#  {'tag': 'avinetworks/se:18.2.8-9117-20200302.065724',
#   'tp': {'clair': 969,
#    'gc': 1420,
#    'grype': 1482,
#    'scout': 534,
#    'snyk': 795,
#    'trivy': 535},
#   'fp': {'clair': 114,
#    'gc': 130,
#    'grype': 1016,
#    'scout': 4,
#    'snyk': 1,
#    'trivy': 0},
#   'fn': {'clair': 639,
#    'gc': 188,
#    'grype': 126,
#    'scout': 1074,
#    'snyk': 813,
#    'trivy': 1073},
#   'tn': {'clair': 1151,
#    'gc': 1135,
#    'grype': 249,
#    'scout': 1261,
#    'snyk': 1264,
#    'trivy': 1265},
#   'precision': {'clair': 0.8947368421052632,
#    'gc': 0.9161290322580645,
#    'grype': 0.5932746196957566,
#    'scout': 0.9925650557620818,
#    'snyk': 0.9987437185929648,
#    'trivy': 1.0},
#   'recall': {'clair': 0.6026119402985075,
#    'gc': 0.8830845771144279,
#    'grype': 0.9216417910447762,
#    'scout': 0.332089552238806,
#    'snyk': 0.4944029850746269,
#    'trivy': 0.3327114427860697},
#   'accuracy': {'clair': 0.7379046293073442,
#    'gc': 0.8893143056038983,
#    'grype': 0.602506091193874,
#    'scout': 0.6247824573616428,
#    'snyk': 0.7166724678036895,
#    'trivy': 0.6265227984684998},
#   'f1': {'clair': 0.7201783723522853,
#    'gc': 0.8993033565547816,
#    'grype': 0.7218704335119338,
#    'scout': 0.4976700838769805,
#    'snyk': 0.6613976705490849,
#    'trivy': 0.49930004666355576}},
#  {'tag': 'silasbw/hello:916c7001',
#   'tp': {'clair': 0,
#    'gc': 289,
#    'grype': 298,
#    'scout': 46,
#    'snyk': 254,
#    'trivy': 219},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 1, 'scout': 3, 'snyk': 27, 'trivy': 0},
#   'fn': {'clair': 300,
#    'gc': 11,
#    'grype': 2,
#    'scout': 254,
#    'snyk': 46,
#    'trivy': 81},
#   'tn': {'clair': 31,
#    'gc': 31,
#    'grype': 30,
#    'scout': 28,
#    'snyk': 4,
#    'trivy': 31},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 0.9966555183946488,
#    'scout': 0.9387755102040817,
#    'snyk': 0.9039145907473309,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.9633333333333334,
#    'grype': 0.9933333333333333,
#    'scout': 0.15333333333333332,
#    'snyk': 0.8466666666666667,
#    'trivy': 0.73},
#   'accuracy': {'clair': 0.09365558912386707,
#    'gc': 0.9667673716012085,
#    'grype': 0.9909365558912386,
#    'scout': 0.22356495468277945,
#    'snyk': 0.7794561933534743,
#    'trivy': 0.7552870090634441},
#   'f1': {'clair': 0.0,
#    'gc': 0.9813242784380306,
#    'grype': 0.9949916527545909,
#    'scout': 0.26361031518624634,
#    'snyk': 0.8743545611015491,
#    'trivy': 0.8439306358381503}},
#  {'tag': 'osixia/openldap:release-1.4.0-dev-amd64',
#   'tp': {'clair': 416,
#    'gc': 503,
#    'grype': 512,
#    'scout': 371,
#    'snyk': 416,
#    'trivy': 435},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 1, 'scout': 9, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 96,
#    'gc': 9,
#    'grype': 0,
#    'scout': 141,
#    'snyk': 96,
#    'trivy': 77},
#   'tn': {'clair': 10,
#    'gc': 11,
#    'grype': 10,
#    'scout': 2,
#    'snyk': 11,
#    'trivy': 11},
#   'precision': {'clair': 0.9976019184652278,
#    'gc': 1.0,
#    'grype': 0.9980506822612085,
#    'scout': 0.9763157894736842,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.8125,
#    'gc': 0.982421875,
#    'grype': 1.0,
#    'scout': 0.724609375,
#    'snyk': 0.8125,
#    'trivy': 0.849609375},
#   'accuracy': {'clair': 0.8145315487571702,
#    'gc': 0.982791586998088,
#    'grype': 0.9980879541108987,
#    'scout': 0.7131931166347992,
#    'snyk': 0.8164435946462715,
#    'trivy': 0.8527724665391969},
#   'f1': {'clair': 0.8955866523143166,
#    'gc': 0.9911330049261083,
#    'grype': 0.9990243902439024,
#    'scout': 0.8318385650224216,
#    'snyk': 0.896551724137931,
#    'trivy': 0.9186906019007391}},
#  {'tag': 'prom/graphite-exporter:v0.12.4',
#   'tp': {'clair': 1,
#    'gc': 33,
#    'grype': 39,
#    'scout': 31,
#    'snyk': 6,
#    'trivy': 10},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 2, 'scout': 3, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 38,
#    'gc': 6,
#    'grype': 0,
#    'scout': 8,
#    'snyk': 33,
#    'trivy': 29},
#   'tn': {'clair': 5, 'gc': 5, 'grype': 3, 'scout': 2, 'snyk': 5, 'trivy': 5},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.9512195121951219,
#    'scout': 0.9117647058823529,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.02564102564102564,
#    'gc': 0.8461538461538461,
#    'grype': 1.0,
#    'scout': 0.7948717948717948,
#    'snyk': 0.15384615384615385,
#    'trivy': 0.2564102564102564},
#   'accuracy': {'clair': 0.13636363636363635,
#    'gc': 0.8636363636363636,
#    'grype': 0.9545454545454546,
#    'scout': 0.75,
#    'snyk': 0.25,
#    'trivy': 0.3409090909090909},
#   'f1': {'clair': 0.05,
#    'gc': 0.9166666666666666,
#    'grype': 0.975,
#    'scout': 0.8493150684931507,
#    'snyk': 0.2666666666666667,
#    'trivy': 0.4081632653061224}},
#  {'tag': 'hetznercloud/hcloud-csi-driver:v2.6.0',
#   'tp': {'clair': 1, 'gc': 5, 'grype': 10, 'scout': 9, 'snyk': 3, 'trivy': 3},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 8, 'scout': 2, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 9, 'gc': 5, 'grype': 0, 'scout': 1, 'snyk': 7, 'trivy': 7},
#   'tn': {'clair': 10,
#    'gc': 10,
#    'grype': 2,
#    'scout': 8,
#    'snyk': 10,
#    'trivy': 10},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 0.5555555555555556,
#    'scout': 0.8181818181818182,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.1,
#    'gc': 0.5,
#    'grype': 1.0,
#    'scout': 0.9,
#    'snyk': 0.3,
#    'trivy': 0.3},
#   'accuracy': {'clair': 0.55,
#    'gc': 0.75,
#    'grype': 0.6,
#    'scout': 0.85,
#    'snyk': 0.65,
#    'trivy': 0.65},
#   'f1': {'clair': 0.18181818181818182,
#    'gc': 0.6666666666666666,
#    'grype': 0.7142857142857143,
#    'scout': 0.8571428571428572,
#    'snyk': 0.4615384615384615,
#    'trivy': 0.4615384615384615}},
#  {'tag': 'bitnami/mongodb-exporter:0.20.8-debian-10-r4',
#   'tp': {'clair': 187,
#    'gc': 249,
#    'grype': 257,
#    'scout': 180,
#    'snyk': 189,
#    'trivy': 196},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 7, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 70,
#    'gc': 8,
#    'grype': 0,
#    'scout': 77,
#    'snyk': 68,
#    'trivy': 61},
#   'tn': {'clair': 7, 'gc': 7, 'grype': 7, 'scout': 0, 'snyk': 7, 'trivy': 7},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 0.9625668449197861,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.7276264591439688,
#    'gc': 0.9688715953307393,
#    'grype': 1.0,
#    'scout': 0.7003891050583657,
#    'snyk': 0.7354085603112841,
#    'trivy': 0.7626459143968871},
#   'accuracy': {'clair': 0.7348484848484849,
#    'gc': 0.9696969696969697,
#    'grype': 1.0,
#    'scout': 0.6818181818181818,
#    'snyk': 0.7424242424242424,
#    'trivy': 0.7689393939393939},
#   'f1': {'clair': 0.8423423423423423,
#    'gc': 0.9841897233201581,
#    'grype': 1.0,
#    'scout': 0.8108108108108106,
#    'snyk': 0.8475336322869955,
#    'trivy': 0.8653421633554084}},
#  {'tag': 'calico/kube-controllers:release-v3.22-ppc64le',
#   'tp': {'clair': 0,
#    'gc': 62,
#    'grype': 63,
#    'scout': 18,
#    'snyk': 8,
#    'trivy': 22},
#   'fp': {'clair': 1, 'gc': 0, 'grype': 12, 'scout': 1, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 63,
#    'gc': 1,
#    'grype': 0,
#    'scout': 45,
#    'snyk': 55,
#    'trivy': 41},
#   'tn': {'clair': 13,
#    'gc': 14,
#    'grype': 2,
#    'scout': 13,
#    'snyk': 14,
#    'trivy': 14},
#   'precision': {'clair': 0.0,
#    'gc': 1.0,
#    'grype': 0.84,
#    'scout': 0.9473684210526315,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.9841269841269841,
#    'grype': 1.0,
#    'scout': 0.2857142857142857,
#    'snyk': 0.12698412698412698,
#    'trivy': 0.3492063492063492},
#   'accuracy': {'clair': 0.16883116883116883,
#    'gc': 0.987012987012987,
#    'grype': 0.8441558441558441,
#    'scout': 0.4025974025974026,
#    'snyk': 0.2857142857142857,
#    'trivy': 0.4675324675324675},
#   'f1': {'clair': None,
#    'gc': 0.9919999999999999,
#    'grype': 0.9130434782608696,
#    'scout': 0.43902439024390244,
#    'snyk': 0.22535211267605632,
#    'trivy': 0.5176470588235293}},
#  {'tag': 'ibmcom/pause:3.1',
#   'tp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'tn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'precision': {'clair': 1,
#    'gc': 1,
#    'grype': 1,
#    'scout': 1,
#    'snyk': 1,
#    'trivy': 1},
#   'recall': {'clair': 0,
#    'gc': 0,
#    'grype': 0,
#    'scout': 0,
#    'snyk': 0,
#    'trivy': 0},
#   'accuracy': {'clair': None,
#    'gc': None,
#    'grype': None,
#    'scout': None,
#    'snyk': None,
#    'trivy': None},
#   'f1': {'clair': 0.0,
#    'gc': 0.0,
#    'grype': 0.0,
#    'scout': 0.0,
#    'snyk': 0.0,
#    'trivy': 0.0}},
#  {'tag': 'selenoid/vnc:chrome_83.0',
#   'tp': {'clair': 546,
#    'gc': 487,
#    'grype': 532,
#    'scout': 378,
#    'snyk': 524,
#    'trivy': 378},
#   'fp': {'clair': 82, 'gc': 0, 'grype': 43, 'scout': 0, 'snyk': 1, 'trivy': 0},
#   'fn': {'clair': 0,
#    'gc': 59,
#    'grype': 14,
#    'scout': 168,
#    'snyk': 22,
#    'trivy': 168},
#   'tn': {'clair': 44,
#    'gc': 126,
#    'grype': 83,
#    'scout': 126,
#    'snyk': 125,
#    'trivy': 126},
#   'precision': {'clair': 0.8694267515923567,
#    'gc': 1.0,
#    'grype': 0.9252173913043479,
#    'scout': 1.0,
#    'snyk': 0.9980952380952381,
#    'trivy': 1.0},
#   'recall': {'clair': 1.0,
#    'gc': 0.891941391941392,
#    'grype': 0.9743589743589743,
#    'scout': 0.6923076923076923,
#    'snyk': 0.9597069597069597,
#    'trivy': 0.6923076923076923},
#   'accuracy': {'clair': 0.8779761904761905,
#    'gc': 0.9122023809523809,
#    'grype': 0.9151785714285714,
#    'scout': 0.75,
#    'snyk': 0.9657738095238095,
#    'trivy': 0.75},
#   'f1': {'clair': 0.93015332197615,
#    'gc': 0.9428848015488869,
#    'grype': 0.9491525423728814,
#    'scout': 0.8181818181818181,
#    'snyk': 0.9785247432306257,
#    'trivy': 0.8181818181818181}},
#  {'tag': 'istio/galley:1.5.0-beta.2',
#   'tp': {'clair': 356,
#    'gc': 1025,
#    'grype': 1055,
#    'scout': 845,
#    'snyk': 353,
#    'trivy': 785},
#   'fp': {'clair': 62,
#    'gc': 8,
#    'grype': 470,
#    'scout': 6,
#    'snyk': 1,
#    'trivy': 0},
#   'fn': {'clair': 707,
#    'gc': 38,
#    'grype': 8,
#    'scout': 218,
#    'snyk': 710,
#    'trivy': 278},
#   'tn': {'clair': 485,
#    'gc': 539,
#    'grype': 77,
#    'scout': 541,
#    'snyk': 546,
#    'trivy': 547},
#   'precision': {'clair': 0.8516746411483254,
#    'gc': 0.9922555663117134,
#    'grype': 0.6918032786885245,
#    'scout': 0.9929494712103408,
#    'snyk': 0.9971751412429378,
#    'trivy': 1.0},
#   'recall': {'clair': 0.33490122295390407,
#    'gc': 0.9642521166509878,
#    'grype': 0.9924741298212606,
#    'scout': 0.7949200376293509,
#    'snyk': 0.33207902163687675,
#    'trivy': 0.7384760112888052},
#   'accuracy': {'clair': 0.522360248447205,
#    'gc': 0.9714285714285714,
#    'grype': 0.7031055900621118,
#    'scout': 0.8608695652173913,
#    'snyk': 0.5583850931677019,
#    'trivy': 0.8273291925465839},
#   'f1': {'clair': 0.48075624577987847,
#    'gc': 0.9780534351145038,
#    'grype': 0.8153013910355487,
#    'scout': 0.8829676071055381,
#    'snyk': 0.4982357092448835,
#    'trivy': 0.8495670995670995}},
#  {'tag': 'containrrr/watchtower:amd64-1.5.0',
#   'tp': {'clair': 4,
#    'gc': 37,
#    'grype': 47,
#    'scout': 41,
#    'snyk': 1,
#    'trivy': 14},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 43,
#    'gc': 10,
#    'grype': 0,
#    'scout': 6,
#    'snyk': 46,
#    'trivy': 33},
#   'tn': {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'precision': {'clair': 1.0,
#    'gc': 1.0,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0851063829787234,
#    'gc': 0.7872340425531915,
#    'grype': 1.0,
#    'scout': 0.8723404255319149,
#    'snyk': 0.02127659574468085,
#    'trivy': 0.2978723404255319},
#   'accuracy': {'clair': 0.0851063829787234,
#    'gc': 0.7872340425531915,
#    'grype': 1.0,
#    'scout': 0.8723404255319149,
#    'snyk': 0.02127659574468085,
#    'trivy': 0.2978723404255319},
#   'f1': {'clair': 0.1568627450980392,
#    'gc': 0.880952380952381,
#    'grype': 1.0,
#    'scout': 0.9318181818181819,
#    'snyk': 0.04166666666666667,
#    'trivy': 0.45901639344262296}},
#  {'tag': 'jaegertracing/jaeger-agent:1.54',
#   'tp': {'clair': 0, 'gc': 2, 'grype': 7, 'scout': 7, 'snyk': 2, 'trivy': 2},
#   'fp': {'clair': 0, 'gc': 0, 'grype': 3, 'scout': 0, 'snyk': 0, 'trivy': 0},
#   'fn': {'clair': 7, 'gc': 5, 'grype': 0, 'scout': 0, 'snyk': 5, 'trivy': 5},
#   'tn': {'clair': 3, 'gc': 3, 'grype': 0, 'scout': 3, 'snyk': 3, 'trivy': 3},
#   'precision': {'clair': 1,
#    'gc': 1.0,
#    'grype': 0.7,
#    'scout': 1.0,
#    'snyk': 1.0,
#    'trivy': 1.0},
#   'recall': {'clair': 0.0,
#    'gc': 0.2857142857142857,
#    'grype': 1.0,
#    'scout': 1.0,
#    'snyk': 0.2857142857142857,
#    'trivy': 0.2857142857142857},
#   'accuracy': {'clair': 0.3,
#    'gc': 0.5,
#    'grype': 0.7,
#    'scout': 1.0,
#    'snyk': 0.5,
#    'trivy': 0.5},
#   'f1': {'clair': 0.0,
#    'gc': 0.4444444444444445,
#    'grype': 0.8235294117647058,
#    'scout': 1.0,
#    'snyk': 0.4444444444444445,
#    'trivy': 0.4444444444444445}},
#  ...]

# %%
pd.DataFrame.from_dict(numbers)
# Out:
#                                                     tag  \
# 0     weaveworksdemos/user-db:6bc65ab9fd43a905a05090...
# 1                docker/ucp-interlock-proxy:3.3.0-beta1
# 2                  jrottenberg/ffmpeg:4.2.8-rockylinux8
# 3                        praqma/network-multitool:extra
# 4                          runatlantis/atlantis:v0.10.0
# ...                                                 ...
# 3186  balena/aarch64-supervisor:remove-nuc-from-extr...
# 3187  appsmith/appsmith-editor:7ae511f402e8907d024f5...
# 3188   circleci/openjdk:16.0.2-jdk-buster-node-browsers
# 3189            defensative/mikesplain-openvas-update:9
# 3190  weaveworksdemos/user-db:12590594348a6cf20d2d91...
#
#                                                      tp  \
# 0     {'clair': 0, 'gc': 155, 'grype': 155, 'scout':...
# 1     {'clair': 11, 'gc': 10, 'grype': 11, 'scout': ...
# 2     {'clair': 0, 'gc': 38, 'grype': 42, 'scout': 4...
# 3     {'clair': 139, 'gc': 138, 'grype': 139, 'scout...
# 4     {'clair': 42, 'gc': 156, 'grype': 165, 'scout'...
# ...                                                 ...
# 3186  {'clair': 42, 'gc': 59, 'grype': 60, 'scout': ...
# 3187  {'clair': 32, 'gc': 32, 'grype': 32, 'scout': ...
# 3188  {'clair': 914, 'gc': 1824, 'grype': 935, 'scou...
# 3189  {'clair': 1040, 'gc': 1238, 'grype': 1063, 'sc...
# 3190  {'clair': 0, 'gc': 156, 'grype': 156, 'scout':...
#
#                                                      fp  \
# 0     {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, ...
# 1     {'clair': 0, 'gc': 0, 'grype': 57, 'scout': 0,...
# 2     {'clair': 0, 'gc': 0, 'grype': 221, 'scout': 0...
# 3     {'clair': 0, 'gc': 0, 'grype': 110, 'scout': 0...
# 4     {'clair': 1, 'gc': 0, 'grype': 85, 'scout': 7,...
# ...                                                 ...
# 3186  {'clair': 0, 'gc': 0, 'grype': 67, 'scout': 0,...
# 3187  {'clair': 0, 'gc': 0, 'grype': 22, 'scout': 0,...
# 3188  {'clair': 0, 'gc': 91, 'grype': 2, 'scout': 4,...
# 3189  {'clair': 131, 'gc': 380, 'grype': 336, 'scout...
# 3190  {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, ...
#
#                                                      fn  \
# 0     {'clair': 157, 'gc': 2, 'grype': 2, 'scout': 1...
# 1     {'clair': 0, 'gc': 1, 'grype': 0, 'scout': 0, ...
# 2     {'clair': 42, 'gc': 4, 'grype': 0, 'scout': 0,...
# 3     {'clair': 0, 'gc': 1, 'grype': 0, 'scout': 0, ...
# 4     {'clair': 123, 'gc': 9, 'grype': 0, 'scout': 2...
# ...                                                 ...
# 3186  {'clair': 18, 'gc': 1, 'grype': 0, 'scout': 0,...
# 3187  {'clair': 0, 'gc': 0, 'grype': 0, 'scout': 0, ...
# 3188  {'clair': 922, 'gc': 12, 'grype': 901, 'scout'...
# 3189  {'clair': 387, 'gc': 189, 'grype': 364, 'scout...
# 3190  {'clair': 158, 'gc': 2, 'grype': 2, 'scout': 1...
#
#                                                      tn  \
# 0     {'clair': 1, 'gc': 1, 'grype': 1, 'scout': 1, ...
# 1     {'clair': 57, 'gc': 57, 'grype': 0, 'scout': 5...
# 2     {'clair': 221, 'gc': 221, 'grype': 0, 'scout':...
# 3     {'clair': 110, 'gc': 110, 'grype': 0, 'scout':...
# 4     {'clair': 92, 'gc': 93, 'grype': 8, 'scout': 8...
# ...                                                 ...
# 3186  {'clair': 67, 'gc': 67, 'grype': 0, 'scout': 6...
# 3187  {'clair': 22, 'gc': 22, 'grype': 0, 'scout': 2...
# 3188  {'clair': 114, 'gc': 23, 'grype': 112, 'scout'...
# 3189  {'clair': 730, 'gc': 481, 'grype': 525, 'scout...
# 3190  {'clair': 1, 'gc': 1, 'grype': 1, 'scout': 1, ...
#
#                                               precision  \
# 0     {'clair': 1, 'gc': 1.0, 'grype': 1.0, 'scout':...
# 1     {'clair': 1.0, 'gc': 1.0, 'grype': 0.161764705...
# 2     {'clair': 1, 'gc': 1.0, 'grype': 0.15969581749...
# 3     {'clair': 1.0, 'gc': 1.0, 'grype': 0.558232931...
# 4     {'clair': 0.9767441860465116, 'gc': 1.0, 'gryp...
# ...                                                 ...
# 3186  {'clair': 1.0, 'gc': 1.0, 'grype': 0.472440944...
# 3187  {'clair': 1.0, 'gc': 1.0, 'grype': 0.592592592...
# 3188  {'clair': 1.0, 'gc': 0.9524804177545692, 'gryp...
# 3189  {'clair': 0.888129803586678, 'gc': 0.765142150...
# 3190  {'clair': 1, 'gc': 1.0, 'grype': 1.0, 'scout':...
#
#                                                  recall  \
# 0     {'clair': 0.0, 'gc': 0.9872611464968153, 'gryp...
# 1     {'clair': 1.0, 'gc': 0.9090909090909091, 'gryp...
# 2     {'clair': 0.0, 'gc': 0.9047619047619048, 'gryp...
# 3     {'clair': 1.0, 'gc': 0.9928057553956835, 'gryp...
# 4     {'clair': 0.2545454545454545, 'gc': 0.94545454...
# ...                                                 ...
# 3186  {'clair': 0.7, 'gc': 0.9833333333333333, 'gryp...
# 3187  {'clair': 1.0, 'gc': 1.0, 'grype': 1.0, 'scout...
# 3188  {'clair': 0.49782135076252726, 'gc': 0.9934640...
# 3189  {'clair': 0.728801681850035, 'gc': 0.867554309...
# 3190  {'clair': 0.0, 'gc': 0.9873417721518988, 'gryp...
#
#                                                accuracy  \
# 0     {'clair': 0.006329113924050633, 'gc': 0.987341...
# 1     {'clair': 1.0, 'gc': 0.9852941176470589, 'gryp...
# 2     {'clair': 0.8403041825095057, 'gc': 0.98479087...
# 3     {'clair': 1.0, 'gc': 0.9959839357429718, 'gryp...
# 4     {'clair': 0.5193798449612403, 'gc': 0.96511627...
# ...                                                 ...
# 3186  {'clair': 0.8582677165354331, 'gc': 0.99212598...
# 3187  {'clair': 1.0, 'gc': 1.0, 'grype': 0.592592592...
# 3188  {'clair': 0.5271794871794871, 'gc': 0.94717948...
# 3189  {'clair': 0.7736013986013986, 'gc': 0.75131118...
# 3190  {'clair': 0.006289308176100629, 'gc': 0.987421...
#
#                                                      f1
# 0     {'clair': 0.0, 'gc': 0.9935897435897436, 'gryp...
# 1     {'clair': 1.0, 'gc': 0.9523809523809523, 'gryp...
# 2     {'clair': 0.0, 'gc': 0.9500000000000001, 'gryp...
# 3     {'clair': 1.0, 'gc': 0.996389891696751, 'grype...
# 4     {'clair': 0.4038461538461538, 'gc': 0.97196261...
# ...                                                 ...
# 3186  {'clair': 0.8235294117647058, 'gc': 0.99159663...
# 3187  {'clair': 1.0, 'gc': 1.0, 'grype': 0.744186046...
# 3188  {'clair': 0.6647272727272727, 'gc': 0.97254065...
# 3189  {'clair': 0.8006158583525789, 'gc': 0.81313628...
# 3190  {'clair': 0.0, 'gc': 0.9936305732484078, 'gryp...
#
# [3191 rows x 9 columns]

# %%
numbers2 = {
    "tp": [],
    "fp": [],
    "fn": [],
    "tn": [],
    "precision": [],
    "recall": [],
    "accuracy": [],
    "f1": []
}

# %%
for key in ["tp", "fp", "fn", "tn"]:
    res = []
    for tag in tags:
        r = {"tag": tag}
        d = next(t for t in per_tag if t["tag"] == tag)
        for s in scanners:
            r[s] = d["res"][key]["num"][s]
        res.append(r)
    numbers2[key] = res

# %%
for key in ["precision", "recall", "accuracy", "f1"]:
    res = []
    for tag in tags:
        r = {"tag": tag}
        d = next(t for t in per_tag if t["tag"] == tag)
        for s in scanners:
            r[s] = d["metrics"][key][s]
        res.append(r)
    numbers2[key] = res

# %%
pd.DataFrame.from_dict(numbers2["precision"]).to_clipboard(excel=True)

# %%
pd.DataFrame.from_dict(numbers2["recall"]).to_clipboard(excel=True)

# %%
pd.DataFrame.from_dict(numbers2["accuracy"]).to_clipboard(excel=True)

# %%
pd.DataFrame.from_dict(numbers2["f1"]).to_clipboard(excel=True)

# %% [markdown]
# # numbers 2

# %%
per_tag = []
for tag in tags:
    filename = tag.replace(":", "_").replace("/", "_")
    with open(f"../final_results/per_tag_res2/{filename}.json", "r") as f:
        per_tag.append(json.load(f))

# %%
numbers2 = {
    "tp": [],
    "fp": [],
    "fn": [],
    "tn": [],
    "precision": [],
    "recall": [],
    "accuracy": [],
    "f1": []
}

# %%
for key in ["tp", "fp", "fn", "tn"]:
    res = []
    for tag in tags:
        r = {"tag": tag}
        d = next(t for t in per_tag if t["tag"] == tag)
        for s in scanners:
            r[s] = d["res"][key]["num"][s]
        res.append(r)
    numbers2[key] = res

# %%
for key in ["precision", "recall", "accuracy", "f1"]:
    res = []
    for tag in tags:
        r = {"tag": tag}
        d = next(t for t in per_tag if t["tag"] == tag)
        for s in scanners:
            r[s] = d["metrics"][key][s]
        res.append(r)
    numbers2[key] = res

# %%
pd.DataFrame.from_dict(numbers2["tp"])
# Out:
#                                                     tag  clair    gc  grype  \
# 0              databus23/concourse-swift-resource:1.0.0      0     0      0
# 1              apicurio/apicurio-studio-ui:0.2.54.Final      0   772    923
# 2     governmentpaas/curl-ssl:0d0f9395c8643e96813a60...     11    11     11
# 3              bitnami/external-dns:0.12.2-debian-11-r0    149   190    196
# 4                     datadog/cluster-agent:7.45.1-rc.1     58    72     85
# ...                                                 ...    ...   ...    ...
# 3186                                cypress/base:16.5.0   1030  1971   1075
# 3187                               casanode/welcome:x86     29    25     29
# 3188                      grafana/promtail:main-209b281     96   138    144
# 3189                  casanode/syslog:x86-develop-2.0.1      0     1      1
# 3190  logdna/logdna-agent:3.5.7-20231127.585fba28aad...     82    96    101
#
#       scout  snyk  trivy
# 0         0     0      0
# 1       181   910    922
# 2        11    11     11
# 3       115   159    159
# 4        80    59     68
# ...     ...   ...    ...
# 3186    815  1055   1983
# 3187     29    29     29
# 3188     86   104    111
# 3189      0     0      0
# 3190     47    94     92
#
# [3191 rows x 7 columns]

# %%
precision = pd.DataFrame.from_dict(numbers2["precision"])#.to_clipboard(excel=True)
precision
# Out:
#                                                     tag     clair        gc  \
# 0              databus23/concourse-swift-resource:1.0.0  1.000000  1.000000
# 1              apicurio/apicurio-studio-ui:0.2.54.Final  1.000000  1.000000
# 2     governmentpaas/curl-ssl:0d0f9395c8643e96813a60...  1.000000  1.000000
# 3              bitnami/external-dns:0.12.2-debian-11-r0  0.993333  1.000000
# 4                     datadog/cluster-agent:7.45.1-rc.1  0.773333  1.000000
# ...                                                 ...       ...       ...
# 3186                                cypress/base:16.5.0  1.000000  1.000000
# 3187                               casanode/welcome:x86  1.000000  1.000000
# 3188                      grafana/promtail:main-209b281  1.000000  1.000000
# 3189                  casanode/syslog:x86-develop-2.0.1  1.000000  0.011765
# 3190  logdna/logdna-agent:3.5.7-20231127.585fba28aad...  1.000000  1.000000
#
#          grype     scout      snyk  trivy
# 0     0.000000  1.000000  1.000000    1.0
# 1     0.988223  0.878641  0.984848    1.0
# 2     0.687500  0.916667  1.000000    1.0
# 3     1.000000  0.942623  1.000000    1.0
# 4     1.000000  0.952381  0.983333    1.0
# ...        ...       ...       ...    ...
# 3186  0.999071  0.996333  0.983225    1.0
# 3187  0.337209  1.000000  1.000000    1.0
# 3188  0.993103  0.934783  0.990476    1.0
# 3189  0.333333  1.000000  1.000000    1.0
# 3190  0.990196  0.796610  1.000000    1.0
#
# [3191 rows x 7 columns]

# %%
precision = precision[scanners].mean().reset_index(name="precision")
precision
# Out:
#    index  precision
# 0  clair   0.936613
# 1     gc   0.967638
# 2  grype   0.779448
# 3  scout   0.957454
# 4   snyk   0.976087
# 5  trivy   0.981234

# %%
recall = pd.DataFrame.from_dict(numbers2["recall"])#.to_clipboard(excel=True)
recall
# Out:
#                                                     tag     clair        gc  \
# 0              databus23/concourse-swift-resource:1.0.0  0.000000  0.000000
# 1              apicurio/apicurio-studio-ui:0.2.54.Final  0.000000  0.828326
# 2     governmentpaas/curl-ssl:0d0f9395c8643e96813a60...  1.000000  1.000000
# 3              bitnami/external-dns:0.12.2-debian-11-r0  0.760204  0.969388
# 4                     datadog/cluster-agent:7.45.1-rc.1  0.682353  0.847059
# ...                                                 ...       ...       ...
# 3186                                cypress/base:16.5.0  0.512438  0.980597
# 3187                               casanode/welcome:x86  1.000000  0.862069
# 3188                      grafana/promtail:main-209b281  0.666667  0.958333
# 3189                  casanode/syslog:x86-develop-2.0.1  0.000000  1.000000
# 3190  logdna/logdna-agent:3.5.7-20231127.585fba28aad...  0.796117  0.932039
#
#          grype     scout      snyk     trivy
# 0     0.000000  0.000000  0.000000  0.000000
# 1     0.990343  0.194206  0.976395  0.989270
# 2     1.000000  1.000000  1.000000  1.000000
# 3     1.000000  0.586735  0.811224  0.811224
# 4     1.000000  0.941176  0.694118  0.800000
# ...        ...       ...       ...       ...
# 3186  0.534826  0.405473  0.524876  0.986567
# 3187  1.000000  1.000000  1.000000  1.000000
# 3188  1.000000  0.597222  0.722222  0.770833
# 3189  1.000000  0.000000  0.000000  0.000000
# 3190  0.980583  0.456311  0.912621  0.893204
#
# [3191 rows x 7 columns]

# %%
recall = recall[scanners].mean().reset_index(name="recall")
recall
# Out:
#    index    recall
# 0  clair  0.508230
# 1     gc  0.797892
# 2  grype  0.872988
# 3  scout  0.676369
# 4   snyk  0.611388
# 5  trivy  0.704477

# %%
accuracy = pd.DataFrame.from_dict(numbers2["accuracy"])#.to_clipboard(excel=True)
accuracy = accuracy[scanners].mean().reset_index(name="accuracy")
accuracy
# Out:
#    index  accuracy
# 0  clair  0.626174
# 1     gc  0.871949
# 2  grype  0.730087
# 3  scout  0.754177
# 4   snyk  0.735512
# 5  trivy  0.798177

# %%
f1 = pd.DataFrame.from_dict(numbers2["f1"])#.to_clipboard(excel=True)
f1 = f1[scanners].mean().reset_index(name="f1")
f1
# Out:
#    index        f1
# 0  clair  0.567573
# 1     gc  0.831728
# 2  grype  0.790356
# 3  scout  0.728999
# 4   snyk  0.678270
# 5  trivy  0.764248

# %%
results = pd.merge(precision, recall).merge(accuracy).merge(f1)
results = results.round(2)
results.drop("accuracy", axis=1).to_clipboard(excel=True)
results
# Out:
#    index  precision  recall  accuracy    f1
# 0  clair       0.94    0.51      0.63  0.57
# 1     gc       0.97    0.80      0.87  0.83
# 2  grype       0.78    0.87      0.73  0.79
# 3  scout       0.96    0.68      0.75  0.73
# 4   snyk       0.98    0.61      0.74  0.68
# 5  trivy       0.98    0.70      0.80  0.76

# %%
pngpath = "/Users/shadrunov/private/thesis/final/assets/images/{}.png"

# %%
scanners = results["index"]
values = {
    'Precision': results["precision"],
    'Recall': results["recall"],
}

# colors = ["tab:green", "tab:blue"]
colors = plt.get_cmap("Paired")

x = np.arange(len(scanners))  # the label locations
width = 0.4  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')
# fig.set_size_inches(8, 6)

for attribute, measurement in values.items():
    offset = width * multiplier + 0.5 * width
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors(multiplier + 2))
    ax.bar_label(rects, padding=2)
    multiplier += 1

ax.set_xticks(x + width, scanners)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.1)

plt.savefig(pngpath.format("precisionrecall1"), bbox_inches='tight', dpi=600)
plt.show()

# %%
scanners = results["index"]
values = {
    'f1': results["f1"],
}

# colors = ["tab:green", "tab:blue"]
colors = plt.get_cmap("Set2")

x = np.arange(len(scanners))  # the label locations
width = 0.6  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')
fig.set_size_inches(6, 4)

for attribute, measurement in values.items():
    offset = width * multiplier + 1 * width
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors(multiplier + 2))
    ax.bar_label(rects, padding=2)
    multiplier += 1

ax.set_xticks(x + width, scanners)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1.0)

plt.savefig(pngpath.format("f11"), bbox_inches='tight', dpi=600)
plt.show()
